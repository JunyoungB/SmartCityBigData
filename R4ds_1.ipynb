# %% [markdown]
# <a href="https://colab.research.google.com/github/JunyoungB/SmartCityBigData/blob/main/R4ds_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## R for Data Science 실습
#
# Colab 에서 R 사용: Runtime - Change Runtime type 에서 R로 변경

# %%
library(tidyverse)
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.2
# ✔ ggplot2   3.5.2     ✔ tibble    3.3.0
# ✔ lubridate 1.9.4     ✔ tidyr     1.3.1
# ✔ purrr     1.1.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %% [markdown]
# ## Pipes

# %%
summary(cars)
# Out:
#      speed           dist
#  Min.   : 4.0   Min.   :  2.00
#  1st Qu.:12.0   1st Qu.: 26.00
#  Median :15.0   Median : 36.00
#  Mean   :15.4   Mean   : 42.98
#  3rd Qu.:19.0   3rd Qu.: 56.00
#  Max.   :25.0   Max.   :120.00

# %%
cars %>% summary()
# Out:
#      speed           dist
#  Min.   : 4.0   Min.   :  2.00
#  1st Qu.:12.0   1st Qu.: 26.00
#  Median :15.0   Median : 36.00
#  Mean   :15.4   Mean   : 42.98
#  3rd Qu.:19.0   3rd Qu.: 56.00
#  Max.   :25.0   Max.   :120.00

# %%
head(cars, 3)
# Out:
#   speed dist
# 1 4      2
# 2 4     10
# 3 7      4

# %%
cars %>% head(3)
# Out:
#   speed dist
# 1 4      2
# 2 4     10
# 3 7      4

# %% [markdown]
# ## Data transformation - dplyr
#
# ### nycflights13
#
# Dataset on flights departing New York City in 2013.

# %%
install.packages("nycflights13")
library(nycflights13)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
flights %>% head()
# Out:
#   year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1 2013 1     1   517      515             2         830      819
# 2 2013 1     1   533      529             4         850      830
# 3 2013 1     1   542      540             2         923      850
# 4 2013 1     1   544      545            -1        1004     1022
# 5 2013 1     1   554      600            -6         812      837
# 6 2013 1     1   554      558            -4         740      728
#   arr_delay carrier flight tailnum origin dest air_time distance hour minute
# 1  11       UA      1545   N14228  EWR    IAH  227      1400     5    15
# 2  20       UA      1714   N24211  LGA    IAH  227      1416     5    29
# 3  33       AA      1141   N619AA  JFK    MIA  160      1089     5    40
# 4 -18       B6       725   N804JB  JFK    BQN  183      1576     5    45
# 5 -25       DL       461   N668DN  LGA    ATL  116       762     6     0
# 6  12       UA      1696   N39463  EWR    ORD  150       719     5    58
#   time_hour
# 1 2013-01-01 05:00:00
# 2 2013-01-01 05:00:00
# 3 2013-01-01 05:00:00
# 4 2013-01-01 05:00:00
# 5 2013-01-01 06:00:00
# 6 2013-01-01 05:00:00

# %%
flights %>% dim()
# Out:
# [1] 336776     19

# %% [markdown]
# - __< int >__ stands for integers.
# - __< dbl >__ stands for doubles, or real numbers.
# - __< chr >__ stands for character vectors, or strings.
# - __< dttm >__ stands for date-times (a date + a time).
# - __< lgl >__ stands for logical, vectors that contain only TRUE or FALSE.
# - __< fctr >__ stands for factors, which R uses to represent categorical variables with fixed possible values.
# - __< date >__ stands for dates.

# %% [markdown]
# ### Filter rows with filter()

# %%
filter(flights, month == 1, day == 1) %>% head()
# Out:
#   year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1 2013 1     1   517      515             2         830      819
# 2 2013 1     1   533      529             4         850      830
# 3 2013 1     1   542      540             2         923      850
# 4 2013 1     1   544      545            -1        1004     1022
# 5 2013 1     1   554      600            -6         812      837
# 6 2013 1     1   554      558            -4         740      728
#   arr_delay carrier flight tailnum origin dest air_time distance hour minute
# 1  11       UA      1545   N14228  EWR    IAH  227      1400     5    15
# 2  20       UA      1714   N24211  LGA    IAH  227      1416     5    29
# 3  33       AA      1141   N619AA  JFK    MIA  160      1089     5    40
# 4 -18       B6       725   N804JB  JFK    BQN  183      1576     5    45
# 5 -25       DL       461   N668DN  LGA    ATL  116       762     6     0
# 6  12       UA      1696   N39463  EWR    ORD  150       719     5    58
#   time_hour
# 1 2013-01-01 05:00:00
# 2 2013-01-01 05:00:00
# 3 2013-01-01 05:00:00
# 4 2013-01-01 05:00:00
# 5 2013-01-01 06:00:00
# 6 2013-01-01 05:00:00

# %%
filter(flights, month == 1, day == 1)
# Out:
#     year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1   2013 1     1   517      515             2         830      819
# 2   2013 1     1   533      529             4         850      830
# 3   2013 1     1   542      540             2         923      850
# 4   2013 1     1   544      545            -1        1004     1022
# 5   2013 1     1   554      600            -6         812      837
# 6   2013 1     1   554      558            -4         740      728
# 7   2013 1     1   555      600            -5         913      854
# 8   2013 1     1   557      600            -3         709      723
# 9   2013 1     1   557      600            -3         838      846
# 10  2013 1     1   558      600            -2         753      745
# 11  2013 1     1   558      600            -2         849      851
# 12  2013 1     1   558      600            -2         853      856
# 13  2013 1     1   558      600            -2         924      917
# 14  2013 1     1   558      600            -2         923      937
# 15  2013 1     1   559      600            -1         941      910
# 16  2013 1     1   559      559             0         702      706
# 17  2013 1     1   559      600            -1         854      902
# 18  2013 1     1   600      600             0         851      858
# 19  2013 1     1   600      600             0         837      825
# 20  2013 1     1   601      600             1         844      850
# 21  2013 1     1   602      610            -8         812      820
# 22  2013 1     1   602      605            -3         821      805
# 23  2013 1     1   606      610            -4         858      910
# 24  2013 1     1   606      610            -4         837      845
# 25  2013 1     1   607      607             0         858      915
# 26  2013 1     1   608      600             8         807      735
# 27  2013 1     1   611      600            11         945      931
# 28  2013 1     1   613      610             3         925      921
# 29  2013 1     1   615      615             0        1039     1100
# 30  2013 1     1   615      615             0         833      842
# ⋮   ⋮    ⋮     ⋮   ⋮        ⋮              ⋮         ⋮        ⋮
# 813 2013 1     1   2140     2135             5        210      224
# 814 2013 1     1   2157     2155             2         43       41
# 815 2013 1     1   2158     2200            -2       2254     2307
# 816 2013 1     1   2205     1720           285         46     2040
# 817 2013 1     1   2209     2145            24         58       37
# 818 2013 1     1   2209     2155            14       2400     2337
# 819 2013 1     1   2211     2145            26       2339     2311
# 820 2013 1     1   2217     2229           -12        249      315
# 821 2013 1     1   2217     2130            47        140       27
# 822 2013 1     1   2221     2000           141       2331     2124
# 823 2013 1     1   2224     2200            24       2324     2316
# 824 2013 1     1   2229     2159            30        149      100
# 825 2013 1     1   2240     2245            -5       2340     2356
# 826 2013 1     1   2250     2255            -5       2352     2359
# 827 2013 1     1   2302     2200            62       2342     2253
# 828 2013 1     1   2306     2245            21         28        5
# 829 2013 1     1   2307     2245            22         32     2357
# 830 2013 1     1   2310     2255            15         24       15
# 831 2013 1     1   2312     2000           192         21     2110
# 832 2013 1     1   2323     2200            83         22     2313
# 833 2013 1     1   2326     2130           116        131       18
# 834 2013 1     1   2327     2250            37         32     2359
# 835 2013 1     1   2343     1724           379        314     1938
# 836 2013 1     1   2353     2359            -6        425      445
# 837 2013 1     1   2353     2359            -6        418      442
# 838 2013 1     1   2356     2359            -3        425      437
# 839 2013 1     1     NA     1630            NA         NA     1815
# 840 2013 1     1     NA     1935            NA         NA     2240
# 841 2013 1     1     NA     1500            NA         NA     1825
# 842 2013 1     1     NA      600            NA         NA      901
#     arr_delay carrier flight tailnum origin dest air_time distance hour minute
# 1    11       UA      1545   N14228  EWR    IAH  227      1400     5    15
# 2    20       UA      1714   N24211  LGA    IAH  227      1416     5    29
# 3    33       AA      1141   N619AA  JFK    MIA  160      1089     5    40
# 4   -18       B6       725   N804JB  JFK    BQN  183      1576     5    45
# 5   -25       DL       461   N668DN  LGA    ATL  116       762     6     0
# 6    12       UA      1696   N39463  EWR    ORD  150       719     5    58
# 7    19       B6       507   N516JB  EWR    FLL  158      1065     6     0
# 8   -14       EV      5708   N829AS  LGA    IAD   53       229     6     0
# 9    -8       B6        79   N593JB  JFK    MCO  140       944     6     0
# 10    8       AA       301   N3ALAA  LGA    ORD  138       733     6     0
# 11   -2       B6        49   N793JB  JFK    PBI  149      1028     6     0
# 12   -3       B6        71   N657JB  JFK    TPA  158      1005     6     0
# 13    7       UA       194   N29129  JFK    LAX  345      2475     6     0
# 14  -14       UA      1124   N53441  EWR    SFO  361      2565     6     0
# 15   31       AA       707   N3DUAA  LGA    DFW  257      1389     6     0
# 16   -4       B6      1806   N708JB  JFK    BOS   44       187     5    59
# 17   -8       UA      1187   N76515  EWR    LAS  337      2227     6     0
# 18   -7       B6       371   N595JB  LGA    FLL  152      1076     6     0
# 19   12       MQ      4650   N542MQ  LGA    ATL  134       762     6     0
# 20   -6       B6       343   N644JB  EWR    PBI  147      1023     6     0
# 21   -8       DL      1919   N971DL  LGA    MSP  170      1020     6    10
# 22   16       MQ      4401   N730MQ  LGA    DTW  105       502     6     5
# 23  -12       AA      1895   N633AA  EWR    MIA  152      1085     6    10
# 24   -8       DL      1743   N3739P  JFK    ATL  128       760     6    10
# 25  -17       UA      1077   N53442  EWR    MIA  157      1085     6     7
# 26   32       MQ      3768   N9EAMQ  EWR    ORD  139       719     6     0
# 27   14       UA       303   N532UA  JFK    SFO  366      2586     6     0
# 28    4       B6       135   N635JB  JFK    RSW  175      1074     6    10
# 29  -21       B6       709   N794JB  JFK    SJU  182      1598     6    15
# 30   -9       DL       575   N326NB  EWR    ATL  120       746     6    15
# ⋮   ⋮         ⋮       ⋮      ⋮       ⋮      ⋮    ⋮        ⋮        ⋮    ⋮
# 813 -14       B6       701   N284JB  JFK    SJU  189      1598     21   35
# 814   2       B6        43   N537JB  JFK    MCO  140       944     21   55
# 815 -13       EV      4103   N14998  EWR    BWI   36       169     22    0
# 816 246       AA      1999   N5DNAA  EWR    MIA  146      1085     17   20
# 817  21       B6        35   N608JB  JFK    PBI  143      1028     21   45
# 818  23       B6      1109   N216JB  JFK    RDU   86       427     21   55
# 819  28       B6       104   N228JB  JFK    BUF   64       301     21   45
# 820 -26       B6       713   N547JB  JFK    SJU  191      1598     22   29
# 821  73       B6        21   N516JB  JFK    TPA  163      1005     21   30
# 822 127       EV      4462   N13566  EWR    BUF   56       282     20    0
# 823   8       EV      4206   N16561  EWR    PWM   47       284     22    0
# 824  49       B6        11   N531JB  JFK    FLL  153      1069     21   59
# 825 -16       B6       608   N279JB  JFK    PWM   44       273     22   45
# 826  -7       B6      1018   N521JB  JFK    BOS   37       187     22   55
# 827  49       EV      4276   N13903  EWR    BDL   24       116     22    0
# 828  23       B6        30   N281JB  JFK    ROC   59       264     22   45
# 829  35       B6       128   N178JB  JFK    BTV   59       266     22   45
# 830   9       B6       112   N646JB  JFK    BUF   57       301     22   55
# 831 191       EV      4312   N13958  EWR    DCA   44       199     20    0
# 832  69       EV      4257   N13538  EWR    BTV   44       266     22    0
# 833  73       B6       199   N594JB  JFK    LAS  290      2248     21   30
# 834  33       B6        22   N639JB  JFK    SYR   45       209     22   50
# 835 456       EV      4321   N21197  EWR    MCI  222      1092     17   24
# 836 -20       B6       739   N591JB  JFK    PSE  195      1617     23   59
# 837 -24       B6       707   N794JB  JFK    SJU  185      1598     23   59
# 838 -12       B6       727   N588JB  JFK    BQN  186      1576     23   59
# 839  NA       EV      4308   N18120  EWR    RDU   NA       416     16   30
# 840  NA       AA       791   N3EHAA  LGA    DFW   NA      1389     19   35
# 841  NA       AA      1925   N3EVAA  LGA    MIA   NA      1096     15    0
# 842  NA       B6       125   N618JB  JFK    FLL   NA      1069      6    0
#     time_hour
# 1   2013-01-01 05:00:00
# 2   2013-01-01 05:00:00
# 3   2013-01-01 05:00:00
# 4   2013-01-01 05:00:00
# 5   2013-01-01 06:00:00
# 6   2013-01-01 05:00:00
# 7   2013-01-01 06:00:00
# 8   2013-01-01 06:00:00
# 9   2013-01-01 06:00:00
# 10  2013-01-01 06:00:00
# 11  2013-01-01 06:00:00
# 12  2013-01-01 06:00:00
# 13  2013-01-01 06:00:00
# 14  2013-01-01 06:00:00
# 15  2013-01-01 06:00:00
# 16  2013-01-01 05:00:00
# 17  2013-01-01 06:00:00
# 18  2013-01-01 06:00:00
# 19  2013-01-01 06:00:00
# 20  2013-01-01 06:00:00
# 21  2013-01-01 06:00:00
# 22  2013-01-01 06:00:00
# 23  2013-01-01 06:00:00
# 24  2013-01-01 06:00:00
# 25  2013-01-01 06:00:00
# 26  2013-01-01 06:00:00
# 27  2013-01-01 06:00:00
# 28  2013-01-01 06:00:00
# 29  2013-01-01 06:00:00
# 30  2013-01-01 06:00:00
# ⋮   ⋮
# 813 2013-01-01 21:00:00
# 814 2013-01-01 21:00:00
# 815 2013-01-01 22:00:00
# 816 2013-01-01 17:00:00
# 817 2013-01-01 21:00:00
# 818 2013-01-01 21:00:00
# 819 2013-01-01 21:00:00
# 820 2013-01-01 22:00:00
# 821 2013-01-01 21:00:00
# 822 2013-01-01 20:00:00
# 823 2013-01-01 22:00:00
# 824 2013-01-01 21:00:00
# 825 2013-01-01 22:00:00
# 826 2013-01-01 22:00:00
# 827 2013-01-01 22:00:00
# 828 2013-01-01 22:00:00
# 829 2013-01-01 22:00:00
# 830 2013-01-01 22:00:00
# 831 2013-01-01 20:00:00
# 832 2013-01-01 22:00:00
# 833 2013-01-01 21:00:00
# 834 2013-01-01 22:00:00
# 835 2013-01-01 17:00:00
# 836 2013-01-01 23:00:00
# 837 2013-01-01 23:00:00
# 838 2013-01-01 23:00:00
# 839 2013-01-01 16:00:00
# 840 2013-01-01 19:00:00
# 841 2013-01-01 15:00:00
# 842 2013-01-01 06:00:00

# %%
flights %>% filter(month == 1, day == 1) %>% filter(dest == 'ORD')
# Out:
#    year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1  2013 1     1    554      558            -4        740      728
# 2  2013 1     1    558      600            -2        753      745
# 3  2013 1     1    608      600             8        807      735
# 4  2013 1     1    629      630            -1        824      810
# 5  2013 1     1    656      700            -4        854      850
# 6  2013 1     1    709      700             9        852      832
# 7  2013 1     1    715      713             2        911      850
# 8  2013 1     1    739      745            -6        918      930
# 9  2013 1     1    749      710            39        939      850
# 10 2013 1     1    828      830            -2       1027     1012
# 11 2013 1     1    830      830             0       1018     1015
# 12 2013 1     1    902      903            -1       1048     1045
# 13 2013 1     1    931      930             1       1121     1108
# 14 2013 1     1    940      945            -5       1119     1130
# 15 2013 1     1   1007     1010            -3       1147     1140
# 16 2013 1     1   1037     1030             7       1221     1210
# 17 2013 1     1   1038     1030             8       1223     1202
# 18 2013 1     1   1130     1125             5       1301     1305
# 19 2013 1     1   1158     1200            -2       1338     1331
# 20 2013 1     1   1217     1220            -3       1414     1350
# 21 2013 1     1   1258     1300            -2       1459     1440
# 22 2013 1     1   1356     1259            57       1538     1438
# 23 2013 1     1   1356     1354             2       1537     1526
# 24 2013 1     1   1416     1411             5       1603     1549
# 25 2013 1     1   1419     1420            -1       1557     1550
# 26 2013 1     1   1445     1455           -10       1635     1645
# 27 2013 1     1   1456     1500            -4       1649     1632
# 28 2013 1     1   1529     1457            32       1720     1634
# 29 2013 1     1   1546     1540             6       1753     1748
# 30 2013 1     1   1557     1600            -3       1746     1742
# 31 2013 1     1   1601     1601             0       1750     1735
# 32 2013 1     1   1603     1550            13       1751     1739
# 33 2013 1     1   1605     1610            -5       1804     1800
# 34 2013 1     1   1632     1635            -3       1824     1810
# 35 2013 1     1   1701     1700             1       1856     1840
# 36 2013 1     1   1714     1720            -6       1915     1915
# 37 2013 1     1   1716     1709             7       1902     1846
# 38 2013 1     1   1717     1720            -3       1920     1910
# 39 2013 1     1   1758     1749             9       2020     1943
# 40 2013 1     1   1817     1820            -3       2008     2005
# 41 2013 1     1   1834     1840            -6       2027     2020
# 42 2013 1     1   1834     1800            34       2014     1942
# 43 2013 1     1   1910     1910             0       2126     2107
# 44 2013 1     1   1916     1920            -4       2053     2100
# 45 2013 1     1   2006     2000             6       2132     2130
# 46 2013 1     1   2030     2045           -15       2150     2225
# 47 2013 1     1   2057     2100            -3       2237     2220
#    arr_delay carrier flight tailnum origin dest air_time distance hour minute
# 1   12       UA      1696   N39463  EWR    ORD  150      719       5   58
# 2    8       AA       301   N3ALAA  LGA    ORD  138      733       6    0
# 3   32       MQ      3768   N9EAMQ  EWR    ORD  139      719       6    0
# 4   14       AA       303   N3CYAA  LGA    ORD  140      733       6   30
# 5    4       AA       305   N4WNAA  LGA    ORD  143      733       7    0
# 6   20       UA      1092   N26226  LGA    ORD  135      733       7    0
# 7   21       UA       544   N841UA  EWR    ORD  156      719       7   13
# 8  -12       AA       309   N4WPAA  LGA    ORD  137      733       7   45
# 9   49       MQ      3737   N508MQ  EWR    ORD  148      719       7   10
# 10  15       B6       905   N274JB  JFK    ORD  160      740       8   30
# 11   3       AA       313   N4YCAA  LGA    ORD  137      733       8   30
# 12   3       UA       580   N820UA  EWR    ORD  145      719       9    3
# 13  13       UA       255   N479UA  LGA    ORD  154      733       9   30
# 14 -11       AA       319   N4WJAA  LGA    ORD  133      733       9   45
# 15   7       MQ      3795   N503MQ  EWR    ORD  131      719      10   10
# 16  11       AA       321   N581AA  LGA    ORD  133      733      10   30
# 17  21       UA       985   N423UA  EWR    ORD  149      719      10   30
# 18  -4       AA       327   N3DEAA  LGA    ORD  127      733      11   25
# 19   7       UA       701   N588UA  LGA    ORD  142      733      12    0
# 20  24       MQ      3697   N517MQ  EWR    ORD  143      719      12   20
# 21  19       AA       329   N511AA  LGA    ORD  147      733      13    0
# 22  60       UA        32   N17128  EWR    ORD  135      719      12   59
# 23  11       UA       617   N840UA  LGA    ORD  146      733      13   54
# 24  14       UA       683   N456UA  EWR    ORD  136      719      14   11
# 25   7       MQ      3728   N500MQ  EWR    ORD  136      719      14   20
# 26 -10       AA       337   N4UCAA  LGA    ORD  147      733      14   55
# 27  17       UA       685   N802UA  LGA    ORD  140      733      15    0
# 28  46       UA       459   N497UA  EWR    ORD  138      719      14   57
# 29   5       9E      3338   N904XJ  JFK    ORD  146      740      15   40
# 30   4       UA       687   N487UA  LGA    ORD  143      733      16    0
# 31  15       UA       702   N484UA  EWR    ORD  141      719      16    1
# 32  12       B6       917   N316JB  JFK    ORD  150      740      15   50
# 33   4       AA       341   N569AA  LGA    ORD  146      733      16   10
# 34  14       MQ      3695   N507MQ  EWR    ORD  139      719      16   35
# 35  16       UA       689   N418UA  LGA    ORD  144      733      17    0
# 36   0       AA      1351   N3CVAA  JFK    ORD  146      740      17   20
# 37  16       UA      1623   N19130  EWR    ORD  143      719      17    9
# 38  10       AA       345   N539AA  LGA    ORD  141      733      17   20
# 39  37       UA      1676   N37274  EWR    ORD  135      719      17   49
# 40   3       AA       353   N3AXAA  LGA    ORD  138      733      18   20
# 41   7       MQ      3730   N517MQ  EWR    ORD  137      719      18   40
# 42  32       UA       668   N467UA  LGA    ORD  123      733      18    0
# 43  19       9E      3359   N925XJ  JFK    ORD  141      740      19   10
# 44  -7       AA       359   N3CUAA  LGA    ORD  136      733      19   20
# 45   2       UA      1271   N12218  LGA    ORD  126      733      20    0
# 46 -35       AA       371   N545AA  LGA    ORD  126      733      20   45
# 47  17       MQ      3744   N521MQ  EWR    ORD  133      719      21    0
#    time_hour
# 1  2013-01-01 05:00:00
# 2  2013-01-01 06:00:00
# 3  2013-01-01 06:00:00
# 4  2013-01-01 06:00:00
# 5  2013-01-01 07:00:00
# 6  2013-01-01 07:00:00
# 7  2013-01-01 07:00:00
# 8  2013-01-01 07:00:00
# 9  2013-01-01 07:00:00
# 10 2013-01-01 08:00:00
# 11 2013-01-01 08:00:00
# 12 2013-01-01 09:00:00
# 13 2013-01-01 09:00:00
# 14 2013-01-01 09:00:00
# 15 2013-01-01 10:00:00
# 16 2013-01-01 10:00:00
# 17 2013-01-01 10:00:00
# 18 2013-01-01 11:00:00
# 19 2013-01-01 12:00:00
# 20 2013-01-01 12:00:00
# 21 2013-01-01 13:00:00
# 22 2013-01-01 12:00:00
# 23 2013-01-01 13:00:00
# 24 2013-01-01 14:00:00
# 25 2013-01-01 14:00:00
# 26 2013-01-01 14:00:00
# 27 2013-01-01 15:00:00
# 28 2013-01-01 14:00:00
# 29 2013-01-01 15:00:00
# 30 2013-01-01 16:00:00
# 31 2013-01-01 16:00:00
# 32 2013-01-01 15:00:00
# 33 2013-01-01 16:00:00
# 34 2013-01-01 16:00:00
# 35 2013-01-01 17:00:00
# 36 2013-01-01 17:00:00
# 37 2013-01-01 17:00:00
# 38 2013-01-01 17:00:00
# 39 2013-01-01 17:00:00
# 40 2013-01-01 18:00:00
# 41 2013-01-01 18:00:00
# 42 2013-01-01 18:00:00
# 43 2013-01-01 19:00:00
# 44 2013-01-01 19:00:00
# 45 2013-01-01 20:00:00
# 46 2013-01-01 20:00:00
# 47 2013-01-01 21:00:00

# %%
flights %>% filter(month == 1, day == 1, dest == 'ORD')
# Out:
#    year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1  2013 1     1    554      558            -4        740      728
# 2  2013 1     1    558      600            -2        753      745
# 3  2013 1     1    608      600             8        807      735
# 4  2013 1     1    629      630            -1        824      810
# 5  2013 1     1    656      700            -4        854      850
# 6  2013 1     1    709      700             9        852      832
# 7  2013 1     1    715      713             2        911      850
# 8  2013 1     1    739      745            -6        918      930
# 9  2013 1     1    749      710            39        939      850
# 10 2013 1     1    828      830            -2       1027     1012
# 11 2013 1     1    830      830             0       1018     1015
# 12 2013 1     1    902      903            -1       1048     1045
# 13 2013 1     1    931      930             1       1121     1108
# 14 2013 1     1    940      945            -5       1119     1130
# 15 2013 1     1   1007     1010            -3       1147     1140
# 16 2013 1     1   1037     1030             7       1221     1210
# 17 2013 1     1   1038     1030             8       1223     1202
# 18 2013 1     1   1130     1125             5       1301     1305
# 19 2013 1     1   1158     1200            -2       1338     1331
# 20 2013 1     1   1217     1220            -3       1414     1350
# 21 2013 1     1   1258     1300            -2       1459     1440
# 22 2013 1     1   1356     1259            57       1538     1438
# 23 2013 1     1   1356     1354             2       1537     1526
# 24 2013 1     1   1416     1411             5       1603     1549
# 25 2013 1     1   1419     1420            -1       1557     1550
# 26 2013 1     1   1445     1455           -10       1635     1645
# 27 2013 1     1   1456     1500            -4       1649     1632
# 28 2013 1     1   1529     1457            32       1720     1634
# 29 2013 1     1   1546     1540             6       1753     1748
# 30 2013 1     1   1557     1600            -3       1746     1742
# 31 2013 1     1   1601     1601             0       1750     1735
# 32 2013 1     1   1603     1550            13       1751     1739
# 33 2013 1     1   1605     1610            -5       1804     1800
# 34 2013 1     1   1632     1635            -3       1824     1810
# 35 2013 1     1   1701     1700             1       1856     1840
# 36 2013 1     1   1714     1720            -6       1915     1915
# 37 2013 1     1   1716     1709             7       1902     1846
# 38 2013 1     1   1717     1720            -3       1920     1910
# 39 2013 1     1   1758     1749             9       2020     1943
# 40 2013 1     1   1817     1820            -3       2008     2005
# 41 2013 1     1   1834     1840            -6       2027     2020
# 42 2013 1     1   1834     1800            34       2014     1942
# 43 2013 1     1   1910     1910             0       2126     2107
# 44 2013 1     1   1916     1920            -4       2053     2100
# 45 2013 1     1   2006     2000             6       2132     2130
# 46 2013 1     1   2030     2045           -15       2150     2225
# 47 2013 1     1   2057     2100            -3       2237     2220
#    arr_delay carrier flight tailnum origin dest air_time distance hour minute
# 1   12       UA      1696   N39463  EWR    ORD  150      719       5   58
# 2    8       AA       301   N3ALAA  LGA    ORD  138      733       6    0
# 3   32       MQ      3768   N9EAMQ  EWR    ORD  139      719       6    0
# 4   14       AA       303   N3CYAA  LGA    ORD  140      733       6   30
# 5    4       AA       305   N4WNAA  LGA    ORD  143      733       7    0
# 6   20       UA      1092   N26226  LGA    ORD  135      733       7    0
# 7   21       UA       544   N841UA  EWR    ORD  156      719       7   13
# 8  -12       AA       309   N4WPAA  LGA    ORD  137      733       7   45
# 9   49       MQ      3737   N508MQ  EWR    ORD  148      719       7   10
# 10  15       B6       905   N274JB  JFK    ORD  160      740       8   30
# 11   3       AA       313   N4YCAA  LGA    ORD  137      733       8   30
# 12   3       UA       580   N820UA  EWR    ORD  145      719       9    3
# 13  13       UA       255   N479UA  LGA    ORD  154      733       9   30
# 14 -11       AA       319   N4WJAA  LGA    ORD  133      733       9   45
# 15   7       MQ      3795   N503MQ  EWR    ORD  131      719      10   10
# 16  11       AA       321   N581AA  LGA    ORD  133      733      10   30
# 17  21       UA       985   N423UA  EWR    ORD  149      719      10   30
# 18  -4       AA       327   N3DEAA  LGA    ORD  127      733      11   25
# 19   7       UA       701   N588UA  LGA    ORD  142      733      12    0
# 20  24       MQ      3697   N517MQ  EWR    ORD  143      719      12   20
# 21  19       AA       329   N511AA  LGA    ORD  147      733      13    0
# 22  60       UA        32   N17128  EWR    ORD  135      719      12   59
# 23  11       UA       617   N840UA  LGA    ORD  146      733      13   54
# 24  14       UA       683   N456UA  EWR    ORD  136      719      14   11
# 25   7       MQ      3728   N500MQ  EWR    ORD  136      719      14   20
# 26 -10       AA       337   N4UCAA  LGA    ORD  147      733      14   55
# 27  17       UA       685   N802UA  LGA    ORD  140      733      15    0
# 28  46       UA       459   N497UA  EWR    ORD  138      719      14   57
# 29   5       9E      3338   N904XJ  JFK    ORD  146      740      15   40
# 30   4       UA       687   N487UA  LGA    ORD  143      733      16    0
# 31  15       UA       702   N484UA  EWR    ORD  141      719      16    1
# 32  12       B6       917   N316JB  JFK    ORD  150      740      15   50
# 33   4       AA       341   N569AA  LGA    ORD  146      733      16   10
# 34  14       MQ      3695   N507MQ  EWR    ORD  139      719      16   35
# 35  16       UA       689   N418UA  LGA    ORD  144      733      17    0
# 36   0       AA      1351   N3CVAA  JFK    ORD  146      740      17   20
# 37  16       UA      1623   N19130  EWR    ORD  143      719      17    9
# 38  10       AA       345   N539AA  LGA    ORD  141      733      17   20
# 39  37       UA      1676   N37274  EWR    ORD  135      719      17   49
# 40   3       AA       353   N3AXAA  LGA    ORD  138      733      18   20
# 41   7       MQ      3730   N517MQ  EWR    ORD  137      719      18   40
# 42  32       UA       668   N467UA  LGA    ORD  123      733      18    0
# 43  19       9E      3359   N925XJ  JFK    ORD  141      740      19   10
# 44  -7       AA       359   N3CUAA  LGA    ORD  136      733      19   20
# 45   2       UA      1271   N12218  LGA    ORD  126      733      20    0
# 46 -35       AA       371   N545AA  LGA    ORD  126      733      20   45
# 47  17       MQ      3744   N521MQ  EWR    ORD  133      719      21    0
#    time_hour
# 1  2013-01-01 05:00:00
# 2  2013-01-01 06:00:00
# 3  2013-01-01 06:00:00
# 4  2013-01-01 06:00:00
# 5  2013-01-01 07:00:00
# 6  2013-01-01 07:00:00
# 7  2013-01-01 07:00:00
# 8  2013-01-01 07:00:00
# 9  2013-01-01 07:00:00
# 10 2013-01-01 08:00:00
# 11 2013-01-01 08:00:00
# 12 2013-01-01 09:00:00
# 13 2013-01-01 09:00:00
# 14 2013-01-01 09:00:00
# 15 2013-01-01 10:00:00
# 16 2013-01-01 10:00:00
# 17 2013-01-01 10:00:00
# 18 2013-01-01 11:00:00
# 19 2013-01-01 12:00:00
# 20 2013-01-01 12:00:00
# 21 2013-01-01 13:00:00
# 22 2013-01-01 12:00:00
# 23 2013-01-01 13:00:00
# 24 2013-01-01 14:00:00
# 25 2013-01-01 14:00:00
# 26 2013-01-01 14:00:00
# 27 2013-01-01 15:00:00
# 28 2013-01-01 14:00:00
# 29 2013-01-01 15:00:00
# 30 2013-01-01 16:00:00
# 31 2013-01-01 16:00:00
# 32 2013-01-01 15:00:00
# 33 2013-01-01 16:00:00
# 34 2013-01-01 16:00:00
# 35 2013-01-01 17:00:00
# 36 2013-01-01 17:00:00
# 37 2013-01-01 17:00:00
# 38 2013-01-01 17:00:00
# 39 2013-01-01 17:00:00
# 40 2013-01-01 18:00:00
# 41 2013-01-01 18:00:00
# 42 2013-01-01 18:00:00
# 43 2013-01-01 19:00:00
# 44 2013-01-01 19:00:00
# 45 2013-01-01 20:00:00
# 46 2013-01-01 20:00:00
# 47 2013-01-01 21:00:00

# %%
flights %>% filter(month == 1 & day == 1, dest == 'ORD')
# Out:
#    year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1  2013 1     1    554      558            -4        740      728
# 2  2013 1     1    558      600            -2        753      745
# 3  2013 1     1    608      600             8        807      735
# 4  2013 1     1    629      630            -1        824      810
# 5  2013 1     1    656      700            -4        854      850
# 6  2013 1     1    709      700             9        852      832
# 7  2013 1     1    715      713             2        911      850
# 8  2013 1     1    739      745            -6        918      930
# 9  2013 1     1    749      710            39        939      850
# 10 2013 1     1    828      830            -2       1027     1012
# 11 2013 1     1    830      830             0       1018     1015
# 12 2013 1     1    902      903            -1       1048     1045
# 13 2013 1     1    931      930             1       1121     1108
# 14 2013 1     1    940      945            -5       1119     1130
# 15 2013 1     1   1007     1010            -3       1147     1140
# 16 2013 1     1   1037     1030             7       1221     1210
# 17 2013 1     1   1038     1030             8       1223     1202
# 18 2013 1     1   1130     1125             5       1301     1305
# 19 2013 1     1   1158     1200            -2       1338     1331
# 20 2013 1     1   1217     1220            -3       1414     1350
# 21 2013 1     1   1258     1300            -2       1459     1440
# 22 2013 1     1   1356     1259            57       1538     1438
# 23 2013 1     1   1356     1354             2       1537     1526
# 24 2013 1     1   1416     1411             5       1603     1549
# 25 2013 1     1   1419     1420            -1       1557     1550
# 26 2013 1     1   1445     1455           -10       1635     1645
# 27 2013 1     1   1456     1500            -4       1649     1632
# 28 2013 1     1   1529     1457            32       1720     1634
# 29 2013 1     1   1546     1540             6       1753     1748
# 30 2013 1     1   1557     1600            -3       1746     1742
# 31 2013 1     1   1601     1601             0       1750     1735
# 32 2013 1     1   1603     1550            13       1751     1739
# 33 2013 1     1   1605     1610            -5       1804     1800
# 34 2013 1     1   1632     1635            -3       1824     1810
# 35 2013 1     1   1701     1700             1       1856     1840
# 36 2013 1     1   1714     1720            -6       1915     1915
# 37 2013 1     1   1716     1709             7       1902     1846
# 38 2013 1     1   1717     1720            -3       1920     1910
# 39 2013 1     1   1758     1749             9       2020     1943
# 40 2013 1     1   1817     1820            -3       2008     2005
# 41 2013 1     1   1834     1840            -6       2027     2020
# 42 2013 1     1   1834     1800            34       2014     1942
# 43 2013 1     1   1910     1910             0       2126     2107
# 44 2013 1     1   1916     1920            -4       2053     2100
# 45 2013 1     1   2006     2000             6       2132     2130
# 46 2013 1     1   2030     2045           -15       2150     2225
# 47 2013 1     1   2057     2100            -3       2237     2220
#    arr_delay carrier flight tailnum origin dest air_time distance hour minute
# 1   12       UA      1696   N39463  EWR    ORD  150      719       5   58
# 2    8       AA       301   N3ALAA  LGA    ORD  138      733       6    0
# 3   32       MQ      3768   N9EAMQ  EWR    ORD  139      719       6    0
# 4   14       AA       303   N3CYAA  LGA    ORD  140      733       6   30
# 5    4       AA       305   N4WNAA  LGA    ORD  143      733       7    0
# 6   20       UA      1092   N26226  LGA    ORD  135      733       7    0
# 7   21       UA       544   N841UA  EWR    ORD  156      719       7   13
# 8  -12       AA       309   N4WPAA  LGA    ORD  137      733       7   45
# 9   49       MQ      3737   N508MQ  EWR    ORD  148      719       7   10
# 10  15       B6       905   N274JB  JFK    ORD  160      740       8   30
# 11   3       AA       313   N4YCAA  LGA    ORD  137      733       8   30
# 12   3       UA       580   N820UA  EWR    ORD  145      719       9    3
# 13  13       UA       255   N479UA  LGA    ORD  154      733       9   30
# 14 -11       AA       319   N4WJAA  LGA    ORD  133      733       9   45
# 15   7       MQ      3795   N503MQ  EWR    ORD  131      719      10   10
# 16  11       AA       321   N581AA  LGA    ORD  133      733      10   30
# 17  21       UA       985   N423UA  EWR    ORD  149      719      10   30
# 18  -4       AA       327   N3DEAA  LGA    ORD  127      733      11   25
# 19   7       UA       701   N588UA  LGA    ORD  142      733      12    0
# 20  24       MQ      3697   N517MQ  EWR    ORD  143      719      12   20
# 21  19       AA       329   N511AA  LGA    ORD  147      733      13    0
# 22  60       UA        32   N17128  EWR    ORD  135      719      12   59
# 23  11       UA       617   N840UA  LGA    ORD  146      733      13   54
# 24  14       UA       683   N456UA  EWR    ORD  136      719      14   11
# 25   7       MQ      3728   N500MQ  EWR    ORD  136      719      14   20
# 26 -10       AA       337   N4UCAA  LGA    ORD  147      733      14   55
# 27  17       UA       685   N802UA  LGA    ORD  140      733      15    0
# 28  46       UA       459   N497UA  EWR    ORD  138      719      14   57
# 29   5       9E      3338   N904XJ  JFK    ORD  146      740      15   40
# 30   4       UA       687   N487UA  LGA    ORD  143      733      16    0
# 31  15       UA       702   N484UA  EWR    ORD  141      719      16    1
# 32  12       B6       917   N316JB  JFK    ORD  150      740      15   50
# 33   4       AA       341   N569AA  LGA    ORD  146      733      16   10
# 34  14       MQ      3695   N507MQ  EWR    ORD  139      719      16   35
# 35  16       UA       689   N418UA  LGA    ORD  144      733      17    0
# 36   0       AA      1351   N3CVAA  JFK    ORD  146      740      17   20
# 37  16       UA      1623   N19130  EWR    ORD  143      719      17    9
# 38  10       AA       345   N539AA  LGA    ORD  141      733      17   20
# 39  37       UA      1676   N37274  EWR    ORD  135      719      17   49
# 40   3       AA       353   N3AXAA  LGA    ORD  138      733      18   20
# 41   7       MQ      3730   N517MQ  EWR    ORD  137      719      18   40
# 42  32       UA       668   N467UA  LGA    ORD  123      733      18    0
# 43  19       9E      3359   N925XJ  JFK    ORD  141      740      19   10
# 44  -7       AA       359   N3CUAA  LGA    ORD  136      733      19   20
# 45   2       UA      1271   N12218  LGA    ORD  126      733      20    0
# 46 -35       AA       371   N545AA  LGA    ORD  126      733      20   45
# 47  17       MQ      3744   N521MQ  EWR    ORD  133      719      21    0
#    time_hour
# 1  2013-01-01 05:00:00
# 2  2013-01-01 06:00:00
# 3  2013-01-01 06:00:00
# 4  2013-01-01 06:00:00
# 5  2013-01-01 07:00:00
# 6  2013-01-01 07:00:00
# 7  2013-01-01 07:00:00
# 8  2013-01-01 07:00:00
# 9  2013-01-01 07:00:00
# 10 2013-01-01 08:00:00
# 11 2013-01-01 08:00:00
# 12 2013-01-01 09:00:00
# 13 2013-01-01 09:00:00
# 14 2013-01-01 09:00:00
# 15 2013-01-01 10:00:00
# 16 2013-01-01 10:00:00
# 17 2013-01-01 10:00:00
# 18 2013-01-01 11:00:00
# 19 2013-01-01 12:00:00
# 20 2013-01-01 12:00:00
# 21 2013-01-01 13:00:00
# 22 2013-01-01 12:00:00
# 23 2013-01-01 13:00:00
# 24 2013-01-01 14:00:00
# 25 2013-01-01 14:00:00
# 26 2013-01-01 14:00:00
# 27 2013-01-01 15:00:00
# 28 2013-01-01 14:00:00
# 29 2013-01-01 15:00:00
# 30 2013-01-01 16:00:00
# 31 2013-01-01 16:00:00
# 32 2013-01-01 15:00:00
# 33 2013-01-01 16:00:00
# 34 2013-01-01 16:00:00
# 35 2013-01-01 17:00:00
# 36 2013-01-01 17:00:00
# 37 2013-01-01 17:00:00
# 38 2013-01-01 17:00:00
# 39 2013-01-01 17:00:00
# 40 2013-01-01 18:00:00
# 41 2013-01-01 18:00:00
# 42 2013-01-01 18:00:00
# 43 2013-01-01 19:00:00
# 44 2013-01-01 19:00:00
# 45 2013-01-01 20:00:00
# 46 2013-01-01 20:00:00
# 47 2013-01-01 21:00:00

# %%
flights %>% filter(month == 1 & day == 1 & dest == 'ORD')
# Out:
#    year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1  2013 1     1    554      558            -4        740      728
# 2  2013 1     1    558      600            -2        753      745
# 3  2013 1     1    608      600             8        807      735
# 4  2013 1     1    629      630            -1        824      810
# 5  2013 1     1    656      700            -4        854      850
# 6  2013 1     1    709      700             9        852      832
# 7  2013 1     1    715      713             2        911      850
# 8  2013 1     1    739      745            -6        918      930
# 9  2013 1     1    749      710            39        939      850
# 10 2013 1     1    828      830            -2       1027     1012
# 11 2013 1     1    830      830             0       1018     1015
# 12 2013 1     1    902      903            -1       1048     1045
# 13 2013 1     1    931      930             1       1121     1108
# 14 2013 1     1    940      945            -5       1119     1130
# 15 2013 1     1   1007     1010            -3       1147     1140
# 16 2013 1     1   1037     1030             7       1221     1210
# 17 2013 1     1   1038     1030             8       1223     1202
# 18 2013 1     1   1130     1125             5       1301     1305
# 19 2013 1     1   1158     1200            -2       1338     1331
# 20 2013 1     1   1217     1220            -3       1414     1350
# 21 2013 1     1   1258     1300            -2       1459     1440
# 22 2013 1     1   1356     1259            57       1538     1438
# 23 2013 1     1   1356     1354             2       1537     1526
# 24 2013 1     1   1416     1411             5       1603     1549
# 25 2013 1     1   1419     1420            -1       1557     1550
# 26 2013 1     1   1445     1455           -10       1635     1645
# 27 2013 1     1   1456     1500            -4       1649     1632
# 28 2013 1     1   1529     1457            32       1720     1634
# 29 2013 1     1   1546     1540             6       1753     1748
# 30 2013 1     1   1557     1600            -3       1746     1742
# 31 2013 1     1   1601     1601             0       1750     1735
# 32 2013 1     1   1603     1550            13       1751     1739
# 33 2013 1     1   1605     1610            -5       1804     1800
# 34 2013 1     1   1632     1635            -3       1824     1810
# 35 2013 1     1   1701     1700             1       1856     1840
# 36 2013 1     1   1714     1720            -6       1915     1915
# 37 2013 1     1   1716     1709             7       1902     1846
# 38 2013 1     1   1717     1720            -3       1920     1910
# 39 2013 1     1   1758     1749             9       2020     1943
# 40 2013 1     1   1817     1820            -3       2008     2005
# 41 2013 1     1   1834     1840            -6       2027     2020
# 42 2013 1     1   1834     1800            34       2014     1942
# 43 2013 1     1   1910     1910             0       2126     2107
# 44 2013 1     1   1916     1920            -4       2053     2100
# 45 2013 1     1   2006     2000             6       2132     2130
# 46 2013 1     1   2030     2045           -15       2150     2225
# 47 2013 1     1   2057     2100            -3       2237     2220
#    arr_delay carrier flight tailnum origin dest air_time distance hour minute
# 1   12       UA      1696   N39463  EWR    ORD  150      719       5   58
# 2    8       AA       301   N3ALAA  LGA    ORD  138      733       6    0
# 3   32       MQ      3768   N9EAMQ  EWR    ORD  139      719       6    0
# 4   14       AA       303   N3CYAA  LGA    ORD  140      733       6   30
# 5    4       AA       305   N4WNAA  LGA    ORD  143      733       7    0
# 6   20       UA      1092   N26226  LGA    ORD  135      733       7    0
# 7   21       UA       544   N841UA  EWR    ORD  156      719       7   13
# 8  -12       AA       309   N4WPAA  LGA    ORD  137      733       7   45
# 9   49       MQ      3737   N508MQ  EWR    ORD  148      719       7   10
# 10  15       B6       905   N274JB  JFK    ORD  160      740       8   30
# 11   3       AA       313   N4YCAA  LGA    ORD  137      733       8   30
# 12   3       UA       580   N820UA  EWR    ORD  145      719       9    3
# 13  13       UA       255   N479UA  LGA    ORD  154      733       9   30
# 14 -11       AA       319   N4WJAA  LGA    ORD  133      733       9   45
# 15   7       MQ      3795   N503MQ  EWR    ORD  131      719      10   10
# 16  11       AA       321   N581AA  LGA    ORD  133      733      10   30
# 17  21       UA       985   N423UA  EWR    ORD  149      719      10   30
# 18  -4       AA       327   N3DEAA  LGA    ORD  127      733      11   25
# 19   7       UA       701   N588UA  LGA    ORD  142      733      12    0
# 20  24       MQ      3697   N517MQ  EWR    ORD  143      719      12   20
# 21  19       AA       329   N511AA  LGA    ORD  147      733      13    0
# 22  60       UA        32   N17128  EWR    ORD  135      719      12   59
# 23  11       UA       617   N840UA  LGA    ORD  146      733      13   54
# 24  14       UA       683   N456UA  EWR    ORD  136      719      14   11
# 25   7       MQ      3728   N500MQ  EWR    ORD  136      719      14   20
# 26 -10       AA       337   N4UCAA  LGA    ORD  147      733      14   55
# 27  17       UA       685   N802UA  LGA    ORD  140      733      15    0
# 28  46       UA       459   N497UA  EWR    ORD  138      719      14   57
# 29   5       9E      3338   N904XJ  JFK    ORD  146      740      15   40
# 30   4       UA       687   N487UA  LGA    ORD  143      733      16    0
# 31  15       UA       702   N484UA  EWR    ORD  141      719      16    1
# 32  12       B6       917   N316JB  JFK    ORD  150      740      15   50
# 33   4       AA       341   N569AA  LGA    ORD  146      733      16   10
# 34  14       MQ      3695   N507MQ  EWR    ORD  139      719      16   35
# 35  16       UA       689   N418UA  LGA    ORD  144      733      17    0
# 36   0       AA      1351   N3CVAA  JFK    ORD  146      740      17   20
# 37  16       UA      1623   N19130  EWR    ORD  143      719      17    9
# 38  10       AA       345   N539AA  LGA    ORD  141      733      17   20
# 39  37       UA      1676   N37274  EWR    ORD  135      719      17   49
# 40   3       AA       353   N3AXAA  LGA    ORD  138      733      18   20
# 41   7       MQ      3730   N517MQ  EWR    ORD  137      719      18   40
# 42  32       UA       668   N467UA  LGA    ORD  123      733      18    0
# 43  19       9E      3359   N925XJ  JFK    ORD  141      740      19   10
# 44  -7       AA       359   N3CUAA  LGA    ORD  136      733      19   20
# 45   2       UA      1271   N12218  LGA    ORD  126      733      20    0
# 46 -35       AA       371   N545AA  LGA    ORD  126      733      20   45
# 47  17       MQ      3744   N521MQ  EWR    ORD  133      719      21    0
#    time_hour
# 1  2013-01-01 05:00:00
# 2  2013-01-01 06:00:00
# 3  2013-01-01 06:00:00
# 4  2013-01-01 06:00:00
# 5  2013-01-01 07:00:00
# 6  2013-01-01 07:00:00
# 7  2013-01-01 07:00:00
# 8  2013-01-01 07:00:00
# 9  2013-01-01 07:00:00
# 10 2013-01-01 08:00:00
# 11 2013-01-01 08:00:00
# 12 2013-01-01 09:00:00
# 13 2013-01-01 09:00:00
# 14 2013-01-01 09:00:00
# 15 2013-01-01 10:00:00
# 16 2013-01-01 10:00:00
# 17 2013-01-01 10:00:00
# 18 2013-01-01 11:00:00
# 19 2013-01-01 12:00:00
# 20 2013-01-01 12:00:00
# 21 2013-01-01 13:00:00
# 22 2013-01-01 12:00:00
# 23 2013-01-01 13:00:00
# 24 2013-01-01 14:00:00
# 25 2013-01-01 14:00:00
# 26 2013-01-01 14:00:00
# 27 2013-01-01 15:00:00
# 28 2013-01-01 14:00:00
# 29 2013-01-01 15:00:00
# 30 2013-01-01 16:00:00
# 31 2013-01-01 16:00:00
# 32 2013-01-01 15:00:00
# 33 2013-01-01 16:00:00
# 34 2013-01-01 16:00:00
# 35 2013-01-01 17:00:00
# 36 2013-01-01 17:00:00
# 37 2013-01-01 17:00:00
# 38 2013-01-01 17:00:00
# 39 2013-01-01 17:00:00
# 40 2013-01-01 18:00:00
# 41 2013-01-01 18:00:00
# 42 2013-01-01 18:00:00
# 43 2013-01-01 19:00:00
# 44 2013-01-01 19:00:00
# 45 2013-01-01 20:00:00
# 46 2013-01-01 20:00:00
# 47 2013-01-01 21:00:00

# %%
flights[flights$month ==1 & flights$day ==1,]
# Out:
#     year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1   2013 1     1   517      515             2         830      819
# 2   2013 1     1   533      529             4         850      830
# 3   2013 1     1   542      540             2         923      850
# 4   2013 1     1   544      545            -1        1004     1022
# 5   2013 1     1   554      600            -6         812      837
# 6   2013 1     1   554      558            -4         740      728
# 7   2013 1     1   555      600            -5         913      854
# 8   2013 1     1   557      600            -3         709      723
# 9   2013 1     1   557      600            -3         838      846
# 10  2013 1     1   558      600            -2         753      745
# 11  2013 1     1   558      600            -2         849      851
# 12  2013 1     1   558      600            -2         853      856
# 13  2013 1     1   558      600            -2         924      917
# 14  2013 1     1   558      600            -2         923      937
# 15  2013 1     1   559      600            -1         941      910
# 16  2013 1     1   559      559             0         702      706
# 17  2013 1     1   559      600            -1         854      902
# 18  2013 1     1   600      600             0         851      858
# 19  2013 1     1   600      600             0         837      825
# 20  2013 1     1   601      600             1         844      850
# 21  2013 1     1   602      610            -8         812      820
# 22  2013 1     1   602      605            -3         821      805
# 23  2013 1     1   606      610            -4         858      910
# 24  2013 1     1   606      610            -4         837      845
# 25  2013 1     1   607      607             0         858      915
# 26  2013 1     1   608      600             8         807      735
# 27  2013 1     1   611      600            11         945      931
# 28  2013 1     1   613      610             3         925      921
# 29  2013 1     1   615      615             0        1039     1100
# 30  2013 1     1   615      615             0         833      842
# ⋮   ⋮    ⋮     ⋮   ⋮        ⋮              ⋮         ⋮        ⋮
# 813 2013 1     1   2140     2135             5        210      224
# 814 2013 1     1   2157     2155             2         43       41
# 815 2013 1     1   2158     2200            -2       2254     2307
# 816 2013 1     1   2205     1720           285         46     2040
# 817 2013 1     1   2209     2145            24         58       37
# 818 2013 1     1   2209     2155            14       2400     2337
# 819 2013 1     1   2211     2145            26       2339     2311
# 820 2013 1     1   2217     2229           -12        249      315
# 821 2013 1     1   2217     2130            47        140       27
# 822 2013 1     1   2221     2000           141       2331     2124
# 823 2013 1     1   2224     2200            24       2324     2316
# 824 2013 1     1   2229     2159            30        149      100
# 825 2013 1     1   2240     2245            -5       2340     2356
# 826 2013 1     1   2250     2255            -5       2352     2359
# 827 2013 1     1   2302     2200            62       2342     2253
# 828 2013 1     1   2306     2245            21         28        5
# 829 2013 1     1   2307     2245            22         32     2357
# 830 2013 1     1   2310     2255            15         24       15
# 831 2013 1     1   2312     2000           192         21     2110
# 832 2013 1     1   2323     2200            83         22     2313
# 833 2013 1     1   2326     2130           116        131       18
# 834 2013 1     1   2327     2250            37         32     2359
# 835 2013 1     1   2343     1724           379        314     1938
# 836 2013 1     1   2353     2359            -6        425      445
# 837 2013 1     1   2353     2359            -6        418      442
# 838 2013 1     1   2356     2359            -3        425      437
# 839 2013 1     1     NA     1630            NA         NA     1815
# 840 2013 1     1     NA     1935            NA         NA     2240
# 841 2013 1     1     NA     1500            NA         NA     1825
# 842 2013 1     1     NA      600            NA         NA      901
#     arr_delay carrier flight tailnum origin dest air_time distance hour minute
# 1    11       UA      1545   N14228  EWR    IAH  227      1400     5    15
# 2    20       UA      1714   N24211  LGA    IAH  227      1416     5    29
# 3    33       AA      1141   N619AA  JFK    MIA  160      1089     5    40
# 4   -18       B6       725   N804JB  JFK    BQN  183      1576     5    45
# 5   -25       DL       461   N668DN  LGA    ATL  116       762     6     0
# 6    12       UA      1696   N39463  EWR    ORD  150       719     5    58
# 7    19       B6       507   N516JB  EWR    FLL  158      1065     6     0
# 8   -14       EV      5708   N829AS  LGA    IAD   53       229     6     0
# 9    -8       B6        79   N593JB  JFK    MCO  140       944     6     0
# 10    8       AA       301   N3ALAA  LGA    ORD  138       733     6     0
# 11   -2       B6        49   N793JB  JFK    PBI  149      1028     6     0
# 12   -3       B6        71   N657JB  JFK    TPA  158      1005     6     0
# 13    7       UA       194   N29129  JFK    LAX  345      2475     6     0
# 14  -14       UA      1124   N53441  EWR    SFO  361      2565     6     0
# 15   31       AA       707   N3DUAA  LGA    DFW  257      1389     6     0
# 16   -4       B6      1806   N708JB  JFK    BOS   44       187     5    59
# 17   -8       UA      1187   N76515  EWR    LAS  337      2227     6     0
# 18   -7       B6       371   N595JB  LGA    FLL  152      1076     6     0
# 19   12       MQ      4650   N542MQ  LGA    ATL  134       762     6     0
# 20   -6       B6       343   N644JB  EWR    PBI  147      1023     6     0
# 21   -8       DL      1919   N971DL  LGA    MSP  170      1020     6    10
# 22   16       MQ      4401   N730MQ  LGA    DTW  105       502     6     5
# 23  -12       AA      1895   N633AA  EWR    MIA  152      1085     6    10
# 24   -8       DL      1743   N3739P  JFK    ATL  128       760     6    10
# 25  -17       UA      1077   N53442  EWR    MIA  157      1085     6     7
# 26   32       MQ      3768   N9EAMQ  EWR    ORD  139       719     6     0
# 27   14       UA       303   N532UA  JFK    SFO  366      2586     6     0
# 28    4       B6       135   N635JB  JFK    RSW  175      1074     6    10
# 29  -21       B6       709   N794JB  JFK    SJU  182      1598     6    15
# 30   -9       DL       575   N326NB  EWR    ATL  120       746     6    15
# ⋮   ⋮         ⋮       ⋮      ⋮       ⋮      ⋮    ⋮        ⋮        ⋮    ⋮
# 813 -14       B6       701   N284JB  JFK    SJU  189      1598     21   35
# 814   2       B6        43   N537JB  JFK    MCO  140       944     21   55
# 815 -13       EV      4103   N14998  EWR    BWI   36       169     22    0
# 816 246       AA      1999   N5DNAA  EWR    MIA  146      1085     17   20
# 817  21       B6        35   N608JB  JFK    PBI  143      1028     21   45
# 818  23       B6      1109   N216JB  JFK    RDU   86       427     21   55
# 819  28       B6       104   N228JB  JFK    BUF   64       301     21   45
# 820 -26       B6       713   N547JB  JFK    SJU  191      1598     22   29
# 821  73       B6        21   N516JB  JFK    TPA  163      1005     21   30
# 822 127       EV      4462   N13566  EWR    BUF   56       282     20    0
# 823   8       EV      4206   N16561  EWR    PWM   47       284     22    0
# 824  49       B6        11   N531JB  JFK    FLL  153      1069     21   59
# 825 -16       B6       608   N279JB  JFK    PWM   44       273     22   45
# 826  -7       B6      1018   N521JB  JFK    BOS   37       187     22   55
# 827  49       EV      4276   N13903  EWR    BDL   24       116     22    0
# 828  23       B6        30   N281JB  JFK    ROC   59       264     22   45
# 829  35       B6       128   N178JB  JFK    BTV   59       266     22   45
# 830   9       B6       112   N646JB  JFK    BUF   57       301     22   55
# 831 191       EV      4312   N13958  EWR    DCA   44       199     20    0
# 832  69       EV      4257   N13538  EWR    BTV   44       266     22    0
# 833  73       B6       199   N594JB  JFK    LAS  290      2248     21   30
# 834  33       B6        22   N639JB  JFK    SYR   45       209     22   50
# 835 456       EV      4321   N21197  EWR    MCI  222      1092     17   24
# 836 -20       B6       739   N591JB  JFK    PSE  195      1617     23   59
# 837 -24       B6       707   N794JB  JFK    SJU  185      1598     23   59
# 838 -12       B6       727   N588JB  JFK    BQN  186      1576     23   59
# 839  NA       EV      4308   N18120  EWR    RDU   NA       416     16   30
# 840  NA       AA       791   N3EHAA  LGA    DFW   NA      1389     19   35
# 841  NA       AA      1925   N3EVAA  LGA    MIA   NA      1096     15    0
# 842  NA       B6       125   N618JB  JFK    FLL   NA      1069      6    0
#     time_hour
# 1   2013-01-01 05:00:00
# 2   2013-01-01 05:00:00
# 3   2013-01-01 05:00:00
# 4   2013-01-01 05:00:00
# 5   2013-01-01 06:00:00
# 6   2013-01-01 05:00:00
# 7   2013-01-01 06:00:00
# 8   2013-01-01 06:00:00
# 9   2013-01-01 06:00:00
# 10  2013-01-01 06:00:00
# 11  2013-01-01 06:00:00
# 12  2013-01-01 06:00:00
# 13  2013-01-01 06:00:00
# 14  2013-01-01 06:00:00
# 15  2013-01-01 06:00:00
# 16  2013-01-01 05:00:00
# 17  2013-01-01 06:00:00
# 18  2013-01-01 06:00:00
# 19  2013-01-01 06:00:00
# 20  2013-01-01 06:00:00
# 21  2013-01-01 06:00:00
# 22  2013-01-01 06:00:00
# 23  2013-01-01 06:00:00
# 24  2013-01-01 06:00:00
# 25  2013-01-01 06:00:00
# 26  2013-01-01 06:00:00
# 27  2013-01-01 06:00:00
# 28  2013-01-01 06:00:00
# 29  2013-01-01 06:00:00
# 30  2013-01-01 06:00:00
# ⋮   ⋮
# 813 2013-01-01 21:00:00
# 814 2013-01-01 21:00:00
# 815 2013-01-01 22:00:00
# 816 2013-01-01 17:00:00
# 817 2013-01-01 21:00:00
# 818 2013-01-01 21:00:00
# 819 2013-01-01 21:00:00
# 820 2013-01-01 22:00:00
# 821 2013-01-01 21:00:00
# 822 2013-01-01 20:00:00
# 823 2013-01-01 22:00:00
# 824 2013-01-01 21:00:00
# 825 2013-01-01 22:00:00
# 826 2013-01-01 22:00:00
# 827 2013-01-01 22:00:00
# 828 2013-01-01 22:00:00
# 829 2013-01-01 22:00:00
# 830 2013-01-01 22:00:00
# 831 2013-01-01 20:00:00
# 832 2013-01-01 22:00:00
# 833 2013-01-01 21:00:00
# 834 2013-01-01 22:00:00
# 835 2013-01-01 17:00:00
# 836 2013-01-01 23:00:00
# 837 2013-01-01 23:00:00
# 838 2013-01-01 23:00:00
# 839 2013-01-01 16:00:00
# 840 2013-01-01 19:00:00
# 841 2013-01-01 15:00:00
# 842 2013-01-01 06:00:00

# %%
flights %>% filter(month == 1 & day == 1 & dest %in% c('ORD','LAS'))# %>% head()
# Out:
#    year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1  2013 1     1    554      558            -4        740      728
# 2  2013 1     1    558      600            -2        753      745
# 3  2013 1     1    559      600            -1        854      902
# 4  2013 1     1    608      600             8        807      735
# 5  2013 1     1    629      630            -1        824      810
# 6  2013 1     1    651      655            -4        936      942
# 7  2013 1     1    656      700            -4        854      850
# 8  2013 1     1    709      700             9        852      832
# 9  2013 1     1    715      713             2        911      850
# 10 2013 1     1    739      745            -6        918      930
# 11 2013 1     1    749      710            39        939      850
# 12 2013 1     1    828      830            -2       1027     1012
# 13 2013 1     1    830      830             0       1018     1015
# 14 2013 1     1    902      903            -1       1048     1045
# 15 2013 1     1    931      930             1       1121     1108
# 16 2013 1     1    932      930             2       1219     1225
# 17 2013 1     1    940      945            -5       1119     1130
# 18 2013 1     1   1007     1010            -3       1147     1140
# 19 2013 1     1   1011     1015            -4       1246     1307
# 20 2013 1     1   1037     1030             7       1221     1210
# 21 2013 1     1   1038     1030             8       1223     1202
# 22 2013 1     1   1059     1053             6       1342     1351
# 23 2013 1     1   1130     1125             5       1301     1305
# 24 2013 1     1   1158     1200            -2       1338     1331
# 25 2013 1     1   1217     1220            -3       1414     1350
# 26 2013 1     1   1258     1300            -2       1459     1440
# 27 2013 1     1   1356     1259            57       1538     1438
# 28 2013 1     1   1356     1354             2       1537     1526
# 29 2013 1     1   1416     1411             5       1603     1549
# 30 2013 1     1   1419     1420            -1       1557     1550
# 31 2013 1     1   1445     1455           -10       1635     1645
# 32 2013 1     1   1456     1500            -4       1649     1632
# 33 2013 1     1   1529     1457            32       1720     1634
# 34 2013 1     1   1539     1537             2       1854     1819
# 35 2013 1     1   1546     1540             6       1753     1748
# 36 2013 1     1   1557     1600            -3       1746     1742
# 37 2013 1     1   1559     1605            -6       1844     1912
# 38 2013 1     1   1601     1601             0       1750     1735
# 39 2013 1     1   1603     1550            13       1751     1739
# 40 2013 1     1   1605     1610            -5       1804     1800
# 41 2013 1     1   1632     1635            -3       1824     1810
# 42 2013 1     1   1656     1700            -4       1941     1955
# 43 2013 1     1   1701     1700             1       1856     1840
# 44 2013 1     1   1714     1720            -6       1915     1915
# 45 2013 1     1   1716     1709             7       1902     1846
# 46 2013 1     1   1717     1720            -3       1920     1910
# 47 2013 1     1   1758     1749             9       2020     1943
# 48 2013 1     1   1816     1800            16       2101     2050
# 49 2013 1     1   1817     1820            -3       2008     2005
# 50 2013 1     1   1834     1840            -6       2027     2020
# 51 2013 1     1   1834     1800            34       2014     1942
# 52 2013 1     1   1909     1910            -1       2212     2224
# 53 2013 1     1   1910     1910             0       2126     2107
# 54 2013 1     1   1916     1920            -4       2053     2100
# 55 2013 1     1   1949     1859            50       2237     2153
# 56 2013 1     1   2006     2000             6       2132     2130
# 57 2013 1     1   2030     2045           -15       2150     2225
# 58 2013 1     1   2057     2100            -3       2237     2220
# 59 2013 1     1   2103     2110            -7       2345       17
# 60 2013 1     1   2326     2130           116        131       18
#    arr_delay carrier flight tailnum origin dest air_time distance hour minute
# 1   12       UA      1696   N39463  EWR    ORD  150       719      5   58
# 2    8       AA       301   N3ALAA  LGA    ORD  138       733      6    0
# 3   -8       UA      1187   N76515  EWR    LAS  337      2227      6    0
# 4   32       MQ      3768   N9EAMQ  EWR    ORD  139       719      6    0
# 5   14       AA       303   N3CYAA  LGA    ORD  140       733      6   30
# 6   -6       B6       203   N558JB  JFK    LAS  323      2248      6   55
# 7    4       AA       305   N4WNAA  LGA    ORD  143       733      7    0
# 8   20       UA      1092   N26226  LGA    ORD  135       733      7    0
# 9   21       UA       544   N841UA  EWR    ORD  156       719      7   13
# 10 -12       AA       309   N4WPAA  LGA    ORD  137       733      7   45
# 11  49       MQ      3737   N508MQ  EWR    ORD  148       719      7   10
# 12  15       B6       905   N274JB  JFK    ORD  160       740      8   30
# 13   3       AA       313   N4YCAA  LGA    ORD  137       733      8   30
# 14   3       UA       580   N820UA  EWR    ORD  145       719      9    3
# 15  13       UA       255   N479UA  LGA    ORD  154       733      9   30
# 16  -6       VX       251   N641VA  JFK    LAS  324      2248      9   30
# 17 -11       AA       319   N4WJAA  LGA    ORD  133       733      9   45
# 18   7       MQ      3795   N503MQ  EWR    ORD  131       719     10   10
# 19 -21       DL      1529   N399DA  JFK    LAS  320      2248     10   15
# 20  11       AA       321   N581AA  LGA    ORD  133       733     10   30
# 21  21       UA       985   N423UA  EWR    ORD  149       719     10   30
# 22  -9       UA       369   N451UA  EWR    LAS  325      2227     10   53
# 23  -4       AA       327   N3DEAA  LGA    ORD  127       733     11   25
# 24   7       UA       701   N588UA  LGA    ORD  142       733     12    0
# 25  24       MQ      3697   N517MQ  EWR    ORD  143       719     12   20
# 26  19       AA       329   N511AA  LGA    ORD  147       733     13    0
# 27  60       UA        32   N17128  EWR    ORD  135       719     12   59
# 28  11       UA       617   N840UA  LGA    ORD  146       733     13   54
# 29  14       UA       683   N456UA  EWR    ORD  136       719     14   11
# 30   7       MQ      3728   N500MQ  EWR    ORD  136       719     14   20
# 31 -10       AA       337   N4UCAA  LGA    ORD  147       733     14   55
# 32  17       UA       685   N802UA  LGA    ORD  140       733     15    0
# 33  46       UA       459   N497UA  EWR    ORD  138       719     14   57
# 34  35       UA      1222   N14250  EWR    LAS  342      2227     15   37
# 35   5       9E      3338   N904XJ  JFK    ORD  146       740     15   40
# 36   4       UA       687   N487UA  LGA    ORD  143       733     16    0
# 37 -28       DL        91   N374DA  JFK    LAS  309      2248     16    5
# 38  15       UA       702   N484UA  EWR    ORD  141       719     16    1
# 39  12       B6       917   N316JB  JFK    ORD  150       740     15   50
# 40   4       AA       341   N569AA  LGA    ORD  146       733     16   10
# 41  14       MQ      3695   N507MQ  EWR    ORD  139       719     16   35
# 42 -14       AA       257   N3CAAA  JFK    LAS  322      2248     17    0
# 43  16       UA       689   N418UA  LGA    ORD  144       733     17    0
# 44   0       AA      1351   N3CVAA  JFK    ORD  146       740     17   20
# 45  16       UA      1623   N19130  EWR    ORD  143       719     17    9
# 46  10       AA       345   N539AA  LGA    ORD  141       733     17   20
# 47  37       UA      1676   N37274  EWR    ORD  135       719     17   49
# 48  11       UA       638   N522UA  EWR    LAS  307      2227     18    0
# 49   3       AA       353   N3AXAA  LGA    ORD  138       733     18   20
# 50   7       MQ      3730   N517MQ  EWR    ORD  137       719     18   40
# 51  32       UA       668   N467UA  LGA    ORD  123       733     18    0
# 52 -12       DL      1629   N6710E  JFK    LAS  323      2248     19   10
# 53  19       9E      3359   N925XJ  JFK    ORD  141       740     19   10
# 54  -7       AA       359   N3CUAA  LGA    ORD  136       733     19   20
# 55  44       B6       711   N640JB  JFK    LAS  309      2248     18   59
# 56   2       UA      1271   N12218  LGA    ORD  126       733     20    0
# 57 -35       AA       371   N545AA  LGA    ORD  126       733     20   45
# 58  17       MQ      3744   N521MQ  EWR    ORD  133       719     21    0
# 59 -32       DL      1668   N3738B  JFK    LAS  309      2248     21   10
# 60  73       B6       199   N594JB  JFK    LAS  290      2248     21   30
#    time_hour
# 1  2013-01-01 05:00:00
# 2  2013-01-01 06:00:00
# 3  2013-01-01 06:00:00
# 4  2013-01-01 06:00:00
# 5  2013-01-01 06:00:00
# 6  2013-01-01 06:00:00
# 7  2013-01-01 07:00:00
# 8  2013-01-01 07:00:00
# 9  2013-01-01 07:00:00
# 10 2013-01-01 07:00:00
# 11 2013-01-01 07:00:00
# 12 2013-01-01 08:00:00
# 13 2013-01-01 08:00:00
# 14 2013-01-01 09:00:00
# 15 2013-01-01 09:00:00
# 16 2013-01-01 09:00:00
# 17 2013-01-01 09:00:00
# 18 2013-01-01 10:00:00
# 19 2013-01-01 10:00:00
# 20 2013-01-01 10:00:00
# 21 2013-01-01 10:00:00
# 22 2013-01-01 10:00:00
# 23 2013-01-01 11:00:00
# 24 2013-01-01 12:00:00
# 25 2013-01-01 12:00:00
# 26 2013-01-01 13:00:00
# 27 2013-01-01 12:00:00
# 28 2013-01-01 13:00:00
# 29 2013-01-01 14:00:00
# 30 2013-01-01 14:00:00
# 31 2013-01-01 14:00:00
# 32 2013-01-01 15:00:00
# 33 2013-01-01 14:00:00
# 34 2013-01-01 15:00:00
# 35 2013-01-01 15:00:00
# 36 2013-01-01 16:00:00
# 37 2013-01-01 16:00:00
# 38 2013-01-01 16:00:00
# 39 2013-01-01 15:00:00
# 40 2013-01-01 16:00:00
# 41 2013-01-01 16:00:00
# 42 2013-01-01 17:00:00
# 43 2013-01-01 17:00:00
# 44 2013-01-01 17:00:00
# 45 2013-01-01 17:00:00
# 46 2013-01-01 17:00:00
# 47 2013-01-01 17:00:00
# 48 2013-01-01 18:00:00
# 49 2013-01-01 18:00:00
# 50 2013-01-01 18:00:00
# 51 2013-01-01 18:00:00
# 52 2013-01-01 19:00:00
# 53 2013-01-01 19:00:00
# 54 2013-01-01 19:00:00
# 55 2013-01-01 18:00:00
# 56 2013-01-01 20:00:00
# 57 2013-01-01 20:00:00
# 58 2013-01-01 21:00:00
# 59 2013-01-01 21:00:00
# 60 2013-01-01 21:00:00

# %% [markdown]
# 5.2.4 Exercises
#
# 1. Find all flights that
#   1. Had an arrival delay of two or more hours
#   2. Flew to Houston (IAH or HOU)
#   3. Were operated by United, American, or Delta
#   4. Departed in summer (July, August, and September)
#   5. Arrived more than two hours late, but didn’t leave late
#   6. Were delayed by at least an hour, but made up over 30 minutes in flight
#   7. Departed between midnight and 6am (inclusive)
# 2. Another useful dplyr filtering helper is between(). What does it do? Can you use it to simplify the code needed to answer the previous challenges?
# 3. How many flights have a missing dep_time? What other variables are missing? What might these rows represent?

# %% [markdown]
# ### Arrange rows with arrange()

# %%
flights %>% filter(dest == "ORD") %>% arrange(year, month, desc(day)) %>% head()
# Out:
#   year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1 2013 1     31  554      600            -6        726      745
# 2 2013 1     31  626      630            -4        740      810
# 3 2013 1     31  626      630            -4        800      810
# 4 2013 1     31  651      700            -9        839      850
# 5 2013 1     31  656      700            -4        829      839
# 6 2013 1     31  710      710             0        901      850
#   arr_delay carrier flight tailnum origin dest air_time distance hour minute
# 1 -19       AA       301   N3DEAA  LGA    ORD  121      733      6     0
# 2 -30       AA       303   N3CXAA  LGA    ORD  116      733      6    30
# 3 -10       B6       905   N339JB  JFK    ORD  124      740      6    30
# 4 -11       AA       305   N4XBAA  LGA    ORD  126      733      7     0
# 5 -10       UA       550   N402UA  LGA    ORD  119      733      7     0
# 6  11       MQ      3737   N519MQ  EWR    ORD  121      719      7    10
#   time_hour
# 1 2013-01-31 06:00:00
# 2 2013-01-31 06:00:00
# 3 2013-01-31 06:00:00
# 4 2013-01-31 07:00:00
# 5 2013-01-31 07:00:00
# 6 2013-01-31 07:00:00

# %%
arrange(flights, year, month, day)  %>% head()
# Out:
#   year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1 2013 1     1   517      515             2         830      819
# 2 2013 1     1   533      529             4         850      830
# 3 2013 1     1   542      540             2         923      850
# 4 2013 1     1   544      545            -1        1004     1022
# 5 2013 1     1   554      600            -6         812      837
# 6 2013 1     1   554      558            -4         740      728
#   arr_delay carrier flight tailnum origin dest air_time distance hour minute
# 1  11       UA      1545   N14228  EWR    IAH  227      1400     5    15
# 2  20       UA      1714   N24211  LGA    IAH  227      1416     5    29
# 3  33       AA      1141   N619AA  JFK    MIA  160      1089     5    40
# 4 -18       B6       725   N804JB  JFK    BQN  183      1576     5    45
# 5 -25       DL       461   N668DN  LGA    ATL  116       762     6     0
# 6  12       UA      1696   N39463  EWR    ORD  150       719     5    58
#   time_hour
# 1 2013-01-01 05:00:00
# 2 2013-01-01 05:00:00
# 3 2013-01-01 05:00:00
# 4 2013-01-01 05:00:00
# 5 2013-01-01 06:00:00
# 6 2013-01-01 05:00:00

# %%
arrange(flights, desc(dep_delay)) %>% head()
# Out:
#   year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1 2013 1      9   641      900           1301      1242     1530
# 2 2013 6     15  1432     1935           1137      1607     2120
# 3 2013 1     10  1121     1635           1126      1239     1810
# 4 2013 9     20  1139     1845           1014      1457     2210
# 5 2013 7     22   845     1600           1005      1044     1815
# 6 2013 4     10  1100     1900            960      1342     2211
#   arr_delay carrier flight tailnum origin dest air_time distance hour minute
# 1 1272      HA        51   N384HA  JFK    HNL  640      4983      9    0
# 2 1127      MQ      3535   N504MQ  JFK    CMH   74       483     19   35
# 3 1109      MQ      3695   N517MQ  EWR    ORD  111       719     16   35
# 4 1007      AA       177   N338AA  JFK    SFO  354      2586     18   45
# 5  989      MQ      3075   N665MQ  JFK    CVG   96       589     16    0
# 6  931      DL      2391   N959DL  JFK    TPA  139      1005     19    0
#   time_hour
# 1 2013-01-09 09:00:00
# 2 2013-06-15 19:00:00
# 3 2013-01-10 16:00:00
# 4 2013-09-20 18:00:00
# 5 2013-07-22 16:00:00
# 6 2013-04-10 19:00:00

# %%
flights %>% arrange(dest) %>% head()
# Out:
#   year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1 2013 10    1   1955     2001           -6        2213     2248
# 2 2013 10    2   2010     2001            9        2230     2248
# 3 2013 10    3   1955     2001           -6        2232     2248
# 4 2013 10    4   2017     2001           16        2304     2248
# 5 2013 10    5   1959     1959            0        2226     2246
# 6 2013 10    6   1959     2001           -2        2234     2248
#   arr_delay carrier flight tailnum origin dest air_time distance hour minute
# 1 -35       B6      65     N554JB  JFK    ABQ  230      1826     20    1
# 2 -18       B6      65     N607JB  JFK    ABQ  238      1826     20    1
# 3 -16       B6      65     N591JB  JFK    ABQ  251      1826     20    1
# 4  16       B6      65     N662JB  JFK    ABQ  257      1826     20    1
# 5 -20       B6      65     N580JB  JFK    ABQ  242      1826     19   59
# 6 -14       B6      65     N507JB  JFK    ABQ  240      1826     20    1
#   time_hour
# 1 2013-10-01 20:00:00
# 2 2013-10-02 20:00:00
# 3 2013-10-03 20:00:00
# 4 2013-10-04 20:00:00
# 5 2013-10-05 19:00:00
# 6 2013-10-06 20:00:00

# %%
flights %>% arrange(desc(time_hour)) %>% head()
# Out:
#   year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1 2013 12    31    13     2359            14       439       437
# 2 2013 12    31    18     2359            19       449       444
# 3 2013 12    31  2328     2330            -2       412       409
# 4 2013 12    31  2355     2359            -4       430       440
# 5 2013 12    31  2356     2359            -3       436       445
# 6 2013 12    31    26     2245           101       129      2353
#   arr_delay carrier flight tailnum origin dest air_time distance hour minute
# 1   2       B6       839   N566JB  JFK    BQN  189      1576     23   59
# 2   5       DL       412   N713TW  JFK    SJU  192      1598     23   59
# 3   3       B6      1389   N651JB  EWR    SJU  198      1608     23   30
# 4 -10       B6      1503   N509JB  JFK    SJU  195      1598     23   59
# 5  -9       B6       745   N665JB  JFK    PSE  200      1617     23   59
# 6  96       B6       108   N374JB  JFK    PWM   50       273     22   45
#   time_hour
# 1 2013-12-31 23:00:00
# 2 2013-12-31 23:00:00
# 3 2013-12-31 23:00:00
# 4 2013-12-31 23:00:00
# 5 2013-12-31 23:00:00
# 6 2013-12-31 22:00:00

# %% [markdown]
# 5.3.1 Exercises
# 1. How could you use arrange() to sort all missing values to the start? (Hint: use is.na()).
#
# 2. Sort flights to find the most delayed flights. Find the flights that left earliest.
#
# 3. Sort flights to find the fastest (highest speed) flights.
#
# 4. Which flights travelled the farthest? Which travelled the shortest?

# %% [markdown]
# ### Select columns with select()

# %%
select(flights, year, month, day) %>% head()
# Out:
#   year month day
# 1 2013 1     1
# 2 2013 1     1
# 3 2013 1     1
# 4 2013 1     1
# 5 2013 1     1
# 6 2013 1     1

# %%
select(flights, -c(year:day)) %>% head()
# Out:
#   dep_time sched_dep_time dep_delay arr_time sched_arr_time arr_delay carrier
# 1 517      515             2         830      819            11       UA
# 2 533      529             4         850      830            20       UA
# 3 542      540             2         923      850            33       AA
# 4 544      545            -1        1004     1022           -18       B6
# 5 554      600            -6         812      837           -25       DL
# 6 554      558            -4         740      728            12       UA
#   flight tailnum origin dest air_time distance hour minute time_hour
# 1 1545   N14228  EWR    IAH  227      1400     5    15     2013-01-01 05:00:00
# 2 1714   N24211  LGA    IAH  227      1416     5    29     2013-01-01 05:00:00
# 3 1141   N619AA  JFK    MIA  160      1089     5    40     2013-01-01 05:00:00
# 4  725   N804JB  JFK    BQN  183      1576     5    45     2013-01-01 05:00:00
# 5  461   N668DN  LGA    ATL  116       762     6     0     2013-01-01 06:00:00
# 6 1696   N39463  EWR    ORD  150       719     5    58     2013-01-01 05:00:00

# %%
flights %>% head()
# Out:
#   year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1 2013 1     1   517      515             2         830      819
# 2 2013 1     1   533      529             4         850      830
# 3 2013 1     1   542      540             2         923      850
# 4 2013 1     1   544      545            -1        1004     1022
# 5 2013 1     1   554      600            -6         812      837
# 6 2013 1     1   554      558            -4         740      728
#   arr_delay carrier flight tailnum origin dest air_time distance hour minute
# 1  11       UA      1545   N14228  EWR    IAH  227      1400     5    15
# 2  20       UA      1714   N24211  LGA    IAH  227      1416     5    29
# 3  33       AA      1141   N619AA  JFK    MIA  160      1089     5    40
# 4 -18       B6       725   N804JB  JFK    BQN  183      1576     5    45
# 5 -25       DL       461   N668DN  LGA    ATL  116       762     6     0
# 6  12       UA      1696   N39463  EWR    ORD  150       719     5    58
#   time_hour
# 1 2013-01-01 05:00:00
# 2 2013-01-01 05:00:00
# 3 2013-01-01 05:00:00
# 4 2013-01-01 05:00:00
# 5 2013-01-01 06:00:00
# 6 2013-01-01 05:00:00

# %%
select(flights, year:sched_arr_time) %>% head()
# Out:
#   year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1 2013 1     1   517      515             2         830      819
# 2 2013 1     1   533      529             4         850      830
# 3 2013 1     1   542      540             2         923      850
# 4 2013 1     1   544      545            -1        1004     1022
# 5 2013 1     1   554      600            -6         812      837
# 6 2013 1     1   554      558            -4         740      728

# %%
select(flights, -(year:day)) %>% head()
# Out:
#   dep_time sched_dep_time dep_delay arr_time sched_arr_time arr_delay carrier
# 1 517      515             2         830      819            11       UA
# 2 533      529             4         850      830            20       UA
# 3 542      540             2         923      850            33       AA
# 4 544      545            -1        1004     1022           -18       B6
# 5 554      600            -6         812      837           -25       DL
# 6 554      558            -4         740      728            12       UA
#   flight tailnum origin dest air_time distance hour minute time_hour
# 1 1545   N14228  EWR    IAH  227      1400     5    15     2013-01-01 05:00:00
# 2 1714   N24211  LGA    IAH  227      1416     5    29     2013-01-01 05:00:00
# 3 1141   N619AA  JFK    MIA  160      1089     5    40     2013-01-01 05:00:00
# 4  725   N804JB  JFK    BQN  183      1576     5    45     2013-01-01 05:00:00
# 5  461   N668DN  LGA    ATL  116       762     6     0     2013-01-01 06:00:00
# 6 1696   N39463  EWR    ORD  150       719     5    58     2013-01-01 05:00:00

# %% [markdown]
# ### Helper functions
#
# - starts_with("abc"): matches names that begin with “abc”.
# - ends_with("xyz"): matches names that end with “xyz”.
# - contains("ijk"): matches names that contain “ijk”.
# - num_range("x", 1:3): matches x1, x2 and x3.

# %%
select(flights, starts_with("arr")) %>% head()
# Out:
#   arr_time arr_delay
# 1  830      11
# 2  850      20
# 3  923      33
# 4 1004     -18
# 5  812     -25
# 6  740      12

# %%
select(flights, contains("arr")) %>% head()
# Out:
#   arr_time sched_arr_time arr_delay carrier
# 1  830      819            11       UA
# 2  850      830            20       UA
# 3  923      850            33       AA
# 4 1004     1022           -18       B6
# 5  812      837           -25       DL
# 6  740      728            12       UA

# %% [markdown]
# Rename the variable with rename()

# %%
rename(flights, tail_num = tailnum) %>% head
# Out:
#   year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1 2013 1     1   517      515             2         830      819
# 2 2013 1     1   533      529             4         850      830
# 3 2013 1     1   542      540             2         923      850
# 4 2013 1     1   544      545            -1        1004     1022
# 5 2013 1     1   554      600            -6         812      837
# 6 2013 1     1   554      558            -4         740      728
#   arr_delay carrier flight tail_num origin dest air_time distance hour minute
# 1  11       UA      1545   N14228   EWR    IAH  227      1400     5    15
# 2  20       UA      1714   N24211   LGA    IAH  227      1416     5    29
# 3  33       AA      1141   N619AA   JFK    MIA  160      1089     5    40
# 4 -18       B6       725   N804JB   JFK    BQN  183      1576     5    45
# 5 -25       DL       461   N668DN   LGA    ATL  116       762     6     0
# 6  12       UA      1696   N39463   EWR    ORD  150       719     5    58
#   time_hour
# 1 2013-01-01 05:00:00
# 2 2013-01-01 05:00:00
# 3 2013-01-01 05:00:00
# 4 2013-01-01 05:00:00
# 5 2013-01-01 06:00:00
# 6 2013-01-01 05:00:00

# %% [markdown]
# Or using traditional R using colnames()

# %%
colnames(flights)
# Out:
#  [1] "year"           "month"          "day"            "dep_time"
#  [5] "sched_dep_time" "dep_delay"      "arr_time"       "sched_arr_time"
#  [9] "arr_delay"      "carrier"        "flight"         "tailnum"
# [13] "origin"         "dest"           "air_time"       "distance"
# [17] "hour"           "minute"         "time_hour"

# %%
colnames(flights)[12]
# Out:
# [1] "tailnum"

# %%
colnames(flights)[12] = 'tail_num'

# %%
flights %>% head()
# Out:
#   year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1 2013 1     1   517      515             2         830      819
# 2 2013 1     1   533      529             4         850      830
# 3 2013 1     1   542      540             2         923      850
# 4 2013 1     1   544      545            -1        1004     1022
# 5 2013 1     1   554      600            -6         812      837
# 6 2013 1     1   554      558            -4         740      728
#   arr_delay carrier flight tail_num origin dest air_time distance hour minute
# 1  11       UA      1545   N14228   EWR    IAH  227      1400     5    15
# 2  20       UA      1714   N24211   LGA    IAH  227      1416     5    29
# 3  33       AA      1141   N619AA   JFK    MIA  160      1089     5    40
# 4 -18       B6       725   N804JB   JFK    BQN  183      1576     5    45
# 5 -25       DL       461   N668DN   LGA    ATL  116       762     6     0
# 6  12       UA      1696   N39463   EWR    ORD  150       719     5    58
#   time_hour
# 1 2013-01-01 05:00:00
# 2 2013-01-01 05:00:00
# 3 2013-01-01 05:00:00
# 4 2013-01-01 05:00:00
# 5 2013-01-01 06:00:00
# 6 2013-01-01 05:00:00

# %%
select(flights, time_hour, air_time, everything()) %>% head()
# Out:
#   time_hour           air_time year month day dep_time sched_dep_time dep_delay
# 1 2013-01-01 05:00:00 227      2013 1     1   517      515             2
# 2 2013-01-01 05:00:00 227      2013 1     1   533      529             4
# 3 2013-01-01 05:00:00 160      2013 1     1   542      540             2
# 4 2013-01-01 05:00:00 183      2013 1     1   544      545            -1
# 5 2013-01-01 06:00:00 116      2013 1     1   554      600            -6
# 6 2013-01-01 05:00:00 150      2013 1     1   554      558            -4
#   arr_time sched_arr_time arr_delay carrier flight tail_num origin dest
# 1  830      819            11       UA      1545   N14228   EWR    IAH
# 2  850      830            20       UA      1714   N24211   LGA    IAH
# 3  923      850            33       AA      1141   N619AA   JFK    MIA
# 4 1004     1022           -18       B6       725   N804JB   JFK    BQN
# 5  812      837           -25       DL       461   N668DN   LGA    ATL
# 6  740      728            12       UA      1696   N39463   EWR    ORD
#   distance hour minute
# 1 1400     5    15
# 2 1416     5    29
# 3 1089     5    40
# 4 1576     5    45
# 5  762     6     0
# 6  719     5    58

# %%
flights %>% select( c("dep_time", "dep_delay", "arr_time", "arr_delay")) %>% head()
# Out:
#   dep_time dep_delay arr_time arr_delay
# 1 517       2         830      11
# 2 533       4         850      20
# 3 542       2         923      33
# 4 544      -1        1004     -18
# 5 554      -6         812     -25
# 6 554      -4         740      12

# %%
flights %>% select(dep_time, dep_delay, arr_time, arr_delay) %>% head()
# Out:
#   dep_time dep_delay arr_time arr_delay
# 1 517       2         830      11
# 2 533       4         850      20
# 3 542       2         923      33
# 4 544      -1        1004     -18
# 5 554      -6         812     -25
# 6 554      -4         740      12

# %%
flights %>% select(starts_with("dep"), starts_with("arr")) %>% head()
# Out:
#   dep_time dep_delay arr_time arr_delay
# 1 517       2         830      11
# 2 533       4         850      20
# 3 542       2         923      33
# 4 544      -1        1004     -18
# 5 554      -6         812     -25
# 6 554      -4         740      12

# %%
flights %>% select(dep_time:arr_delay, -c("sched_dep_time", "sched_arr_time") ) %>% head()
# Out:
#   dep_time dep_delay arr_time arr_delay
# 1 517       2         830      11
# 2 533       4         850      20
# 3 542       2         923      33
# 4 544      -1        1004     -18
# 5 554      -6         812     -25
# 6 554      -4         740      12

# %%
flights %>% select(dep_time:arr_delay) %>% head()
# Out:
#   dep_time sched_dep_time dep_delay arr_time sched_arr_time arr_delay
# 1 517      515             2         830      819            11
# 2 533      529             4         850      830            20
# 3 542      540             2         923      850            33
# 4 544      545            -1        1004     1022           -18
# 5 554      600            -6         812      837           -25
# 6 554      558            -4         740      728            12

# %%
flights %>% select(dep_time:arr_delay, -(sched_dep_time, sched_arr_time) ) %>% head()
# Out:
# Error in parse(text = input): <text>:1:56: unexpected ','
# 1: flights %>% select(dep_time:arr_delay, -(sched_dep_time,
#                                                            ^
# Traceback:

# %%
flights %>% select(dep_time:arr_delay, -sched_dep_time, -sched_arr_time) %>% head()
# Out:
#   dep_time dep_delay arr_time arr_delay
# 1 517       2         830      11
# 2 533       4         850      20
# 3 542       2         923      33
# 4 544      -1        1004     -18
# 5 554      -6         812     -25
# 6 554      -4         740      12

# %% [markdown]
# 5.4.1 Exercises
# 1. Brainstorm as many ways as possible to select dep_time, dep_delay, arr_time, and arr_delay from flights.
# 2. What happens if you include the name of a variable multiple times in a select() call?
# 3. What does the any_of() function do? Why might it be helpful in conjunction with this vector?
# ```
# vars <- c("year", "month", "day", "dep_delay", "arr_delay")
# ```

# %% [markdown]
# ### Add new variables with mutate()

# %%
flights %>% select(year:day, ends_with("delay"), distance, air_time) %>% head()
# Out:
#   year month day dep_delay arr_delay distance air_time
# 1 2013 1     1    2         11       1400     227
# 2 2013 1     1    4         20       1416     227
# 3 2013 1     1    2         33       1089     160
# 4 2013 1     1   -1        -18       1576     183
# 5 2013 1     1   -6        -25        762     116
# 6 2013 1     1   -4         12        719     150

# %%
flights %>%
    select(year:day, ends_with("delay"), distance, air_time) %>%
    mutate(gain = dep_delay - arr_delay,
              hours = air_time / 60,
              gain_per_hour = gain / hours) %>% head()
# Out:
#   year month day dep_delay arr_delay distance air_time gain hours
# 1 2013 1     1    2         11       1400     227       -9  3.783333
# 2 2013 1     1    4         20       1416     227      -16  3.783333
# 3 2013 1     1    2         33       1089     160      -31  2.666667
# 4 2013 1     1   -1        -18       1576     183       17  3.050000
# 5 2013 1     1   -6        -25        762     116       19  1.933333
# 6 2013 1     1   -4         12        719     150      -16  2.500000
#   gain_per_hour
# 1  -2.378855
# 2  -4.229075
# 3 -11.625000
# 4   5.573770
# 5   9.827586
# 6  -6.400000

# %%
flights %>%
    select(year:day, ends_with("delay"), distance, air_time) %>%
    mutate(gain = dep_delay - arr_delay,
              hours = air_time / 60,
              gain_per_hour = gain / hours) %>% arrange(gain_per_hour)
# Out:
#        year month day dep_delay arr_delay distance air_time gain hours
# 1      2013  6    24  171       273        94      31       -102 0.5166667
# 2      2013  6    27   62       177       184      36       -115 0.6000000
# 3      2013  7    23   11       122        94      36       -111 0.6000000
# 4      2013 12    17  115       233       187      40       -118 0.6666667
# 5      2013  6    13   -7       106       184      39       -113 0.6500000
# 6      2013  6    27   -8       123       184      46       -131 0.7666667
# 7      2013  3    18   -1       109       187      39       -110 0.6500000
# 8      2013  1    25   39       152       199      42       -113 0.7000000
# 9      2013  5     9    3        94       184      34        -91 0.5666667
# 10     2013  6    13   33       136       184      39       -103 0.6500000
# 11     2013  1    16    9        96       184      33        -87 0.5500000
# 12     2013  6    27    3       103        96      38       -100 0.6333333
# 13     2013  3    18   82       195       187      43       -113 0.7166667
# 14     2013  6    25   -3       108       214      44       -111 0.7333333
# 15     2013  1    25   89       187       169      39        -98 0.6500000
# 16     2013  7     7   -6        88       173      38        -94 0.6333333
# 17     2013  6    13   25       116       195      37        -91 0.6166667
# 18     2013  6    27   85       184       187      41        -99 0.6833333
# 19     2013  4    23    0        94       184      39        -94 0.6500000
# 20     2013  6    23   -5        74        94      33        -79 0.5500000
# 21     2013  8    28   39       127       200      38        -88 0.6333333
# 22     2013  7     1   -3       108       266      48       -111 0.8000000
# 23     2013  7     7   -1       147       214      64       -148 1.0666667
# 24     2013  6     7   76       159       187      36        -83 0.6000000
# 25     2013  7    22   25       156       301      57       -131 0.9500000
# 26     2013  9    11   -2       108       209      49       -110 0.8166667
# 27     2013  6    13   45       132       214      39        -87 0.6500000
# 28     2013  9    12  -11        71       198      37        -82 0.6166667
# 29     2013  4    12   -5        92       214      44        -97 0.7333333
# 30     2013  7     1   10       111       273      46       -101 0.7666667
# ⋮      ⋮    ⋮     ⋮   ⋮         ⋮         ⋮        ⋮        ⋮    ⋮
# 336747 2013 9     25   NA       NA         431     NA       NA   NA
# 336748 2013 9     25   NA       NA         719     NA       NA   NA
# 336749 2013 9     26    2       NA        4963     NA       NA   NA
# 336750 2013 9     26   NA       NA         641     NA       NA   NA
# 336751 2013 9     26   NA       NA         214     NA       NA   NA
# 336752 2013 9     26   NA       NA        1411     NA       NA   NA
# 336753 2013 9     27    3       NA         733     NA       NA   NA
# 336754 2013 9     27  188       NA         461     NA       NA   NA
# 336755 2013 9     27   NA       NA         733     NA       NA   NA
# 336756 2013 9     27   NA       NA         184     NA       NA   NA
# 336757 2013 9     27   NA       NA         719     NA       NA   NA
# 336758 2013 9     27   NA       NA         733     NA       NA   NA
# 336759 2013 9     28   -5       NA         488     NA       NA   NA
# 336760 2013 9     28    8       NA         725     NA       NA   NA
# 336761 2013 9     28  -10       NA        1017     NA       NA   NA
# 336762 2013 9     28  -11       NA        1372     NA       NA   NA
# 336763 2013 9     28   NA       NA         258     NA       NA   NA
# 336764 2013 9     28   NA       NA        2475     NA       NA   NA
# 336765 2013 9     28   NA       NA         529     NA       NA   NA
# 336766 2013 9     29   23       NA        2434     NA       NA   NA
# 336767 2013 9     29   NA       NA         569     NA       NA   NA
# 336768 2013 9     29   NA       NA         719     NA       NA   NA
# 336769 2013 9     29   NA       NA         733     NA       NA   NA
# 336770 2013 9     30   -1       NA         711     NA       NA   NA
# 336771 2013 9     30   NA       NA         764     NA       NA   NA
# 336772 2013 9     30   NA       NA         213     NA       NA   NA
# 336773 2013 9     30   NA       NA         198     NA       NA   NA
# 336774 2013 9     30   NA       NA         764     NA       NA   NA
# 336775 2013 9     30   NA       NA         419     NA       NA   NA
# 336776 2013 9     30   NA       NA         431     NA       NA   NA
#        gain_per_hour
# 1      -197.4194
# 2      -191.6667
# 3      -185.0000
# 4      -177.0000
# 5      -173.8462
# 6      -170.8696
# 7      -169.2308
# 8      -161.4286
# 9      -160.5882
# 10     -158.4615
# 11     -158.1818
# 12     -157.8947
# 13     -157.6744
# 14     -151.3636
# 15     -150.7692
# 16     -148.4211
# 17     -147.5676
# 18     -144.8780
# 19     -144.6154
# 20     -143.6364
# 21     -138.9474
# 22     -138.7500
# 23     -138.7500
# 24     -138.3333
# 25     -137.8947
# 26     -134.6939
# 27     -133.8462
# 28     -132.9730
# 29     -132.2727
# 30     -131.7391
# ⋮      ⋮
# 336747 NA
# 336748 NA
# 336749 NA
# 336750 NA
# 336751 NA
# 336752 NA
# 336753 NA
# 336754 NA
# 336755 NA
# 336756 NA
# 336757 NA
# 336758 NA
# 336759 NA
# 336760 NA
# 336761 NA
# 336762 NA
# 336763 NA
# 336764 NA
# 336765 NA
# 336766 NA
# 336767 NA
# 336768 NA
# 336769 NA
# 336770 NA
# 336771 NA
# 336772 NA
# 336773 NA
# 336774 NA
# 336775 NA
# 336776 NA

# %%
flights %>%
    select(year:day, ends_with("delay"), distance, air_time) %>%
    transmute(gain = dep_delay - arr_delay,
              hours = air_time / 60,
              gain_per_hour = gain / hours) %>% head()
# Out:
#   gain hours    gain_per_hour
# 1  -9  3.783333  -2.378855
# 2 -16  3.783333  -4.229075
# 3 -31  2.666667 -11.625000
# 4  17  3.050000   5.573770
# 5  19  1.933333   9.827586
# 6 -16  2.500000  -6.400000

# %%
flights %>%
    select(year:day, ends_with("delay"), distance, air_time) %>%
    mutate(gain = dep_delay - arr_delay,
              hours = air_time / 60,
              gain_per_hour = gain / hours) %>% select(gain:gain_per_hour) %>% head()
# Out:
#   gain hours    gain_per_hour
# 1  -9  3.783333  -2.378855
# 2 -16  3.783333  -4.229075
# 3 -31  2.666667 -11.625000
# 4  17  3.050000   5.573770
# 5  19  1.933333   9.827586
# 6 -16  2.500000  -6.400000

# %% [markdown]
# 5.5.2 Exercises
# 1. Currently dep_time and sched_dep_time are convenient to look at, but hard to compute with because they’re not really continuous numbers. Convert them to a more convenient representation of number of minutes since midnight.
# 2. Compare air_time with arr_time - dep_time. What do you expect to see? What do you see? What do you need to do to fix it?
# 3. Compare dep_time, sched_dep_time, and dep_delay. How would you expect those three numbers to be related?
# 4. Find the 10 most delayed flights using a ranking function. How do you want to handle ties? Carefully read the documentation for min_rank().
# 5. What does 1:3 + 1:10 return? Why?

# %% [markdown]
# ### Grouped summaries with summarise()

# %%
flights %>% head()
# Out:
#   year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1 2013 1     1   517      515             2         830      819
# 2 2013 1     1   533      529             4         850      830
# 3 2013 1     1   542      540             2         923      850
# 4 2013 1     1   544      545            -1        1004     1022
# 5 2013 1     1   554      600            -6         812      837
# 6 2013 1     1   554      558            -4         740      728
#   arr_delay carrier flight tail_num origin dest air_time distance hour minute
# 1  11       UA      1545   N14228   EWR    IAH  227      1400     5    15
# 2  20       UA      1714   N24211   LGA    IAH  227      1416     5    29
# 3  33       AA      1141   N619AA   JFK    MIA  160      1089     5    40
# 4 -18       B6       725   N804JB   JFK    BQN  183      1576     5    45
# 5 -25       DL       461   N668DN   LGA    ATL  116       762     6     0
# 6  12       UA      1696   N39463   EWR    ORD  150       719     5    58
#   time_hour
# 1 2013-01-01 05:00:00
# 2 2013-01-01 05:00:00
# 3 2013-01-01 05:00:00
# 4 2013-01-01 05:00:00
# 5 2013-01-01 06:00:00
# 6 2013-01-01 05:00:00

# %%
flights %>% group_by(month) %>% summarise(delay = mean(dep_delay, na.rm = TRUE), N = n())
# Out:
#    month delay     N
# 1   1    10.036665 27004
# 2   2    10.816843 24951
# 3   3    13.227076 28834
# 4   4    13.938038 28330
# 5   5    12.986859 28796
# 6   6    20.846332 28243
# 7   7    21.727787 29425
# 8   8    12.611040 29327
# 9   9     6.722476 27574
# 10 10     6.243988 28889
# 11 11     5.435362 27268
# 12 12    16.576688 28135

# %%
flights %>% summarise(delay = mean(dep_delay, na.rm = TRUE), n_delay = n())
# Out:
#   delay    n_delay
# 1 12.63907 336776

# %%
flights %>% group_by(year, month, day) %>%
summarise(delay = mean(dep_delay, na.rm = TRUE), n = n(), delay_sd = sd(dep_delay, na.rm = TRUE)   ) %>% head()
# Out:
# `summarise()` has grouped output by 'year', 'month'. You can override using the
# `.groups` argument.
#   year month day delay     n   delay_sd
# 1 2013 1     1   11.548926 842 45.26135
# 2 2013 1     2   13.858824 943 37.20873
# 3 2013 1     3   10.987832 914 31.45735
# 4 2013 1     4    8.951595 915 27.73426
# 5 2013 1     5    5.732218 720 25.73426
# 6 2013 1     6    7.148014 832 23.16834

# %%
flights %>% group_by(year, month) %>%
summarise(delay = mean(dep_delay, na.rm = TRUE), delay_N = n(), delay_sd = sd(dep_delay, na.rm = TRUE)) %>% head()
# Out:
# `summarise()` has grouped output by 'year'. You can override using the
# `.groups` argument.
#   year month delay    delay_N delay_sd
# 1 2013 1     10.03667 27004   36.39031
# 2 2013 2     10.81684 24951   36.26655
# 3 2013 3     13.22708 28834   40.13097
# 4 2013 4     13.93804 28330   42.96626
# 5 2013 5     12.98686 28796   39.35283
# 6 2013 6     20.84633 28243   51.45694

# %%
flights %>% group_by(origin) %>%
summarise(delay = mean(dep_delay, na.rm = TRUE), sd_delay = sd(dep_delay, na.rm = TRUE)) %>% head()
# Out:
#   origin delay    sd_delay
# 1 EWR    15.10795 41.32370
# 2 JFK    12.11216 39.03507
# 3 LGA    10.34688 39.99302

# %%
flights %>% group_by(dest) %>%
   summarise(count = n(), dist = mean(distance, na.rm = TRUE), delay = mean(arr_delay, na.rm = TRUE) ) %>%
   filter(count > 20, dest != "HNL")
# Out:
#    dest count dist       delay
# 1  ABQ    254 1826.0000   4.3818898
# 2  ACK    265  199.0000   4.8522727
# 3  ALB    439  143.0000  14.3971292
# 4  ATL  17215  757.1082  11.3001128
# 5  AUS   2439 1514.2530   6.0199088
# 6  AVL    275  583.5818   8.0038314
# 7  BDL    443  116.0000   7.0485437
# 8  BGR    375  378.0000   8.0279330
# 9  BHM    297  865.9966  16.8773234
# 10 BNA   6333  758.2135  11.8124589
# 11 BOS  15508  190.6370   2.9143922
# 12 BQN    896 1578.9833   8.2454955
# 13 BTV   2589  265.0915   8.9509960
# 14 BUF   4681  296.8084   8.9459519
# 15 BUR    371 2465.0000   8.1756757
# 16 BWI   1781  179.4183  10.7267338
# 17 BZN     36 1882.0000   7.6000000
# 18 CAE    116  603.5517  41.7641509
# 19 CAK    864  397.0000  19.6983373
# 20 CHO     52  305.0000   9.5000000
# 21 CHS   2884  632.9168  10.5929685
# 22 CLE   4573  414.1743   9.1816113
# 23 CLT  14064  538.0273   7.3603189
# 24 CMH   3524  476.5551  10.6013229
# 25 CRW    138  444.0000  14.6716418
# 26 CVG   3941  575.1599  15.3645638
# 27 DAY   1525  537.1023  12.6804861
# 28 DCA   9705  211.0062   9.0669520
# 29 DEN   7266 1614.6784   8.6065002
# 30 DFW   8738 1383.0430   0.3221268
# ⋮  ⋮    ⋮     ⋮          ⋮
# 67 PHL   1632   94.32353 10.1271901
# 68 PHX   4656 2141.30326  2.0970473
# 69 PIT   2875  334.06122  7.6809905
# 70 PSE    365 1617.00000  7.8715084
# 71 PVD    376  160.00000 16.2346369
# 72 PWM   2352  276.12840 11.6604021
# 73 RDU   8163  426.75769 10.0523810
# 74 RIC   2454  281.40465 20.1112532
# 75 ROC   2416  259.25083 11.5606446
# 76 RSW   3537 1072.85327  3.2381496
# 77 SAN   2737 2437.29923  3.1391657
# 78 SAT    686 1578.34111  6.9453718
# 79 SAV    804  709.18408 15.1295060
# 80 SDF   1157  645.98358 12.6693841
# 81 SEA   3923 2412.66531 -1.0990991
# 82 SFO  13331 2577.92356  2.6728915
# 83 SJC    329 2569.00000  3.4481707
# 84 SJU   5819 1599.83365  2.5205266
# 85 SLC   2467 1986.98662  0.1762546
# 86 SMF    284 2521.00000 12.1099291
# 87 SNA    825 2434.00000 -7.8682266
# 88 SRQ   1211 1044.65153  3.0824313
# 89 STL   4339  878.72321 11.0784645
# 90 STT    522 1626.98276 -3.8359073
# 91 SYR   1761  205.92164  8.9039250
# 92 TPA   7466 1003.93557  7.4085250
# 93 TUL    315 1215.00000 33.6598639
# 94 TVC    101  652.38614 12.9684211
# 95 TYS    631  638.80983 24.0692042
# 96 XNA   1036 1142.50579  7.4657258

# %% [markdown]
# It looks like delays increase with distance up to ~750 miles and then decrease. Maybe as flights get longer there's more ability to make up delays in the air?

# %%
flights %>% group_by(dest) %>%
   summarise(count = n(), dist = mean(distance, na.rm = TRUE), delay = mean(arr_delay, na.rm = TRUE) ) %>%
   filter(count > 20, dest != "HNL") %>%
ggplot(mapping = aes(x = dist, y = delay)) +
  geom_point(aes(size = count), alpha = 1/3) +
  geom_smooth(se = FALSE)
# Out:
# `geom_smooth()` using method = 'loess' and formula = 'y ~ x'
# plot without title

# %% [markdown]
# 5.6.7 Exercises
# 1. Brainstorm at least 5 different ways to assess the typical delay characteristics of a group of flights. Consider the following scenarios:
#   - A flight is 15 minutes early 50% of the time, and 15 minutes late 50% of the time.
#   - A flight is always 10 minutes late.
#   - A flight is 30 minutes early 50% of the time, and 30 minutes late 50% of the time.
#   - 99% of the time a flight is on time. 1% of the time it’s 2 hours late.
# - Which is more important: arrival delay or departure delay?
# 2. Come up with another approach that will give you the same output as not_cancelled %>% count(dest) and not_cancelled %>% count(tailnum, wt = distance) (without using count()).
# 3. Look at the number of cancelled flights per day. Is there a pattern? Is the proportion of cancelled flights related to the average delay?

# %% [markdown]
# ## Data visualization - ggplot

# %%
mpg %>% head()
# Out:
#   manufacturer model displ year cyl trans      drv cty hwy fl class
# 1 audi         a4    1.8   1999 4   auto(l5)   f   18  29  p  compact
# 2 audi         a4    1.8   1999 4   manual(m5) f   21  29  p  compact
# 3 audi         a4    2.0   2008 4   manual(m6) f   20  31  p  compact
# 4 audi         a4    2.0   2008 4   auto(av)   f   21  30  p  compact
# 5 audi         a4    2.8   1999 6   auto(l5)   f   16  26  p  compact
# 6 audi         a4    2.8   1999 6   manual(m5) f   18  26  p  compact

# %%
ggplot(data = mpg, mapping = aes(x = displ, y = hwy)) +
  geom_point() + geom_smooth()
# Out:
# `geom_smooth()` using method = 'loess' and formula = 'y ~ x'
# plot without title

# %%
ggplot(data = mpg) +
  geom_point(mapping = aes(x = displ, y = hwy)) + geom_smooth(mapping = aes(x = displ, y = hwy))
# Out:
# `geom_smooth()` using method = 'loess' and formula = 'y ~ x'
# plot without title

# %% [markdown]
# 3.2.4 Exercises
# 1. Run ggplot(data = mpg). What do you see?
# 2. How many rows are in mpg? How many columns?
# 3. What does the drv variable describe? Read the help for ?mpg to find out.
# 4. Make a scatterplot of hwy vs cyl.
# 5. What happens if you make a scatterplot of class vs drv? Why is the plot not useful?

# %% [markdown]
# ### Aesthetic mappings

# %%
ggplot(data = mpg) +
  geom_point(mapping = aes(x = displ, y = hwy, color = class))
# Out:
# plot without title

# %%
ggplot(data = mpg) +
  geom_point(mapping = aes(x = displ, y = hwy, size = cyl))
# Out:
# plot without title

# %%
ggplot(data = mpg) +
  geom_point(mapping = aes(x = displ, y = hwy), alpha = 0.1)
# Out:
# plot without title

# %%
ggplot(data = mpg) +
  geom_point(mapping = aes(x = displ, y = hwy, alpha = cyl))
# Out:
# plot without title

# %%
ggplot(data = mpg) +
  geom_point(mapping = aes(x = displ, y = hwy, shape = class))
# Out:
# Warning message:
# “The shape palette can deal with a maximum of 6 discrete values because more
# than 6 becomes difficult to discriminate
# ℹ you have requested 7 values. Consider specifying shapes manually if you need
#   that many of them.”
# Warning message:
# “Removed 62 rows containing missing values or values outside the scale range
# (`geom_point()`).”
# plot without title

# %%
ggplot(data = mpg) +
  geom_point(mapping = aes(x = displ, y = hwy), color = "blue")
# Out:
# plot without title

# %%
ggplot(data = mpg) +
  geom_point(mapping = aes(x = displ, y = hwy))
# Out:
# plot without title

# %% [markdown]
# declare global mapping information in ggplot()

# %%
ggplot(data = mpg, mapping = aes(x = displ, y = hwy)) +
  geom_point()
# Out:
# plot without title

# %% [markdown]
# Add graphical layers

# %%
ggplot(data = mpg) +
  geom_point(mapping = aes(x = displ, y = hwy)) + geom_smooth(mapping = aes(x = displ, y = hwy)) + geom_line(mapping = aes(x = displ, y = hwy))
# Out:
# `geom_smooth()` using method = 'loess' and formula = 'y ~ x'
# plot without title

# %%
ggplot(data = mpg, mapping = aes(x = displ, y = hwy, color = class)) + geom_point()
# Out:
# plot without title

# %%
ggplot(data = mpg, mapping = aes(x = displ, y = hwy, size = cyl)) + geom_point()
# Out:
# plot without title

# %%
ggplot(data = mpg, mapping = aes(x = displ, y = hwy, alpha = class)) + geom_point()
# Out:
# Warning message:
# “Using alpha for a discrete variable is not advised.”
# plot without title

# %%
ggplot(data = mpg, mapping = aes(x = displ, y = hwy, shape = class)) + geom_point()
# Out:
# Warning message:
# “The shape palette can deal with a maximum of 6 discrete values because more
# than 6 becomes difficult to discriminate
# ℹ you have requested 7 values. Consider specifying shapes manually if you need
#   that many of them.”
# Warning message:
# “Removed 62 rows containing missing values or values outside the scale range
# (`geom_point()`).”
# plot without title

# %% [markdown]
# 3.3.1 Exercises
# 1. What’s gone wrong with this code? Why are the points not blue?
#
# ```
# ggplot(data = mpg) +
#   geom_point(mapping = aes(x = displ, y = hwy, color = "blue"))
# ```
# 2. Which variables in mpg are categorical? Which variables are continuous? (Hint: type ?mpg to read the documentation for the dataset). How can you see this information when you run mpg?
# 3. Map a continuous variable to color, size, and shape. How do these aesthetics behave differently for categorical vs. continuous variables?
# 4. What happens if you map the same variable to multiple aesthetics?
# 5. What does the stroke aesthetic do? What shapes does it work with? (Hint: use ?geom_point)
# 6. What happens if you map an aesthetic to something other than a variable name, like aes(colour = displ < 5)? Note, you’ll also need to specify x and y.

# %% [markdown]
# ### Facets

# %%
ggplot(data = mpg) +
  geom_point(mapping = aes(x = displ, y = hwy)) +
  facet_wrap(~ class, nrow = 3)
# Out:
# plot without title

# %%
mpg %>% head()
# Out:
#   manufacturer model displ year cyl trans      drv cty hwy fl class
# 1 audi         a4    1.8   1999 4   auto(l5)   f   18  29  p  compact
# 2 audi         a4    1.8   1999 4   manual(m5) f   21  29  p  compact
# 3 audi         a4    2.0   2008 4   manual(m6) f   20  31  p  compact
# 4 audi         a4    2.0   2008 4   auto(av)   f   21  30  p  compact
# 5 audi         a4    2.8   1999 6   auto(l5)   f   16  26  p  compact
# 6 audi         a4    2.8   1999 6   manual(m5) f   18  26  p  compact

# %%
ggplot(data = mpg) +
  geom_point(mapping = aes(x = displ, y = hwy)) +
  facet_grid(drv ~ cyl)
# Out:
# plot without title

# %% [markdown]
# 3.5.1 Exercises
# 1. What happens if you facet on a continuous variable?
#
# 2. What do the empty cells in plot with facet_grid(drv ~ cyl) mean? How do they relate to this plot?
# ```
# ggplot(data = mpg) +
#   geom_point(mapping = aes(x = drv, y = cyl))
# ```
# 3. What plots does the following code make? What does . do?
# ```
# ggplot(data = mpg) +
#   geom_point(mapping = aes(x = displ, y = hwy)) +
#   facet_grid(drv ~ .)
# ```
# ```
# ggplot(data = mpg) +
#   geom_point(mapping = aes(x = displ, y = hwy)) +
#   facet_grid(. ~ cyl)
# ```
# 4. Take the first faceted plot in this section:
#
# ```
# ggplot(data = mpg) +
#   geom_point(mapping = aes(x = displ, y = hwy)) +
#   facet_wrap(~ class, nrow = 2)
# ```
# - What are the advantages to using faceting instead of the colour aesthetic? What are the disadvantages? How might the balance change if you had a larger dataset?
#
# 5. Read ?facet_wrap. What does nrow do? What does ncol do? What other options control the layout of the individual panels? Why doesn’t facet_grid() have nrow and ncol arguments?
# 6. When using facet_grid() you should usually put the variable with more unique levels in the columns. Why?

# %% [markdown]
# ### Geometric objects

# %%
ggplot(data = mpg) +
  geom_point(mapping = aes(x = displ, y = hwy))
# Out:
# plot without title

# %%
ggplot(data = mpg) +
  geom_smooth(mapping = aes(x = displ, y = hwy))
# Out:
# `geom_smooth()` using method = 'loess' and formula = 'y ~ x'
# plot without title

# %% [markdown]
# To display multiple geoms in the same plot, add multiple geom functions to ggplot():

# %%
ggplot(data = mpg, mapping = aes(x = displ, y = hwy)) +
  geom_point() + geom_smooth()
# Out:
# `geom_smooth()` using method = 'loess' and formula = 'y ~ x'
# plot without title

# %%
ggplot(data = mpg) +
  geom_smooth(mapping = aes(x = displ, y = hwy, linetype = drv))
# Out:
# `geom_smooth()` using method = 'loess' and formula = 'y ~ x'
# plot without title

# %%
ggplot(data = mpg) +
  geom_point(mapping = aes(x = displ, y = hwy)) +
  geom_smooth(mapping = aes(x = displ, y = hwy))
# Out:
# `geom_smooth()` using method = 'loess' and formula = 'y ~ x'
# plot without title

# %%
ggplot(data = mpg, mapping = aes(x = displ, y = hwy)) +
  geom_point(mapping = aes(color = class)) +
  geom_smooth()
# Out:
# `geom_smooth()` using method = 'loess' and formula = 'y ~ x'
# plot without title

# %%
ggplot(data = mpg, mapping = aes(x = displ, y = hwy)) +
  geom_point(mapping = aes(color = class)) +
  geom_smooth(data = filter(mpg, class == "subcompact"), se = FALSE)
# Out:
# `geom_smooth()` using method = 'loess' and formula = 'y ~ x'
# plot without title

# %% [markdown]
# 3.6.1 Exercises
# 1. What geom would you use to draw a line chart? A boxplot? A histogram? An area chart?
# 2. Run this code in your head and predict what the output will look like. Then, run the code in R and check your predictions.
# ```
# ggplot(data = mpg, mapping = aes(x = displ, y = hwy, color = drv)) +
#   geom_point() +
#   geom_smooth(se = FALSE)
# ```
# 3. What does show.legend = FALSE do? What happens if you remove it?
# Why do you think I used it earlier in the chapter?
# 4. What does the se argument to geom_smooth() do?
# 5. Will these two graphs look different? Why/why not?
# ```
# ggplot(data = mpg, mapping = aes(x = displ, y = hwy)) +
#   geom_point() +
#   geom_smooth()
# ```
# ```
# ggplot() +
#   geom_point(data = mpg, mapping = aes(x = displ, y = hwy)) +
#   geom_smooth(data = mpg, mapping = aes(x = displ, y = hwy))
# ```
# 6. Recreate the R code necessary to generate the following graphs.
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Statistical transformations

# %%
diamonds %>% head()
# Out:
#   carat cut       color clarity depth table price x    y    z
# 1 0.23  Ideal     E     SI2     61.5  55    326   3.95 3.98 2.43
# 2 0.21  Premium   E     SI1     59.8  61    326   3.89 3.84 2.31
# 3 0.23  Good      E     VS1     56.9  65    327   4.05 4.07 2.31
# 4 0.29  Premium   I     VS2     62.4  58    334   4.20 4.23 2.63
# 5 0.31  Good      J     SI2     63.3  58    335   4.34 4.35 2.75
# 6 0.24  Very Good J     VVS2    62.8  57    336   3.94 3.96 2.48

# %%
ggplot(data = diamonds) +
  geom_bar(mapping = aes(x = cut))
# Out:
# plot without title

# %%
table(diamonds$cut)
# Out:
#      Fair      Good Very Good   Premium     Ideal
#      1610      4906     12082     13791     21551

# %%
demo <- tribble(
  ~cut,         ~freq,
  "Fair",       1610,
  "Good",       4906,
  "Very Good",  12082,
  "Premium",    13791,
  "Ideal",      21551
)
demo
# Out:
#   cut       freq
# 1 Fair       1610
# 2 Good       4906
# 3 Very Good 12082
# 4 Premium   13791
# 5 Ideal     21551

# %%
ggplot(data = demo) +
  geom_bar(mapping = aes(x = cut, y = freq), stat = "identity")
# Out:
# plot without title

# %%
ggplot(data = demo) +
  geom_bar(mapping = aes(x = cut, y = freq))
# Out:
# ERROR while rich displaying an object: Error in `geom_bar()`:
# ! Problem while computing stat.
# ℹ Error occurred in the 1st layer.
# Caused by error in `setup_params()`:
# ! `stat_count()` must only have an x or y aesthetic.
#
# Traceback:
# 1. sapply(x, f, simplify = simplify)
# 2. lapply(X = X, FUN = FUN, ...)
# 3. FUN(X[[i]], ...)
# 4. tryCatch(withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 5. tryCatchList(expr, classes, parentenv, handlers)
# 6. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 7. doTryCatch(return(expr), name, parentenv, handler)
# 8. withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler)
# 9. repr::mime2repr[[mime]](obj)
# 10. repr_text.default(obj)
# 11. paste(capture.output(print(obj)), collapse = "\n")
# 12. capture.output(print(obj))
# 13. withVisible(...elt(i))
# 14. print(obj)
# 15. print.ggplot(obj)
# 16. ggplot_build(x)
# 17. ggplot_build.ggplot(x)
# 18. by_layer(function(l, d) l$compute_statistic(d, layout), layers,
#   .     data, "computing stat")
# 19. try_fetch(for (i in seq_along(data)) {
#   .     out[[i]] <- f(l = layers[[i]], d = data[[i]])
#   . }, error = function(cnd) {
#   .     cli::cli_abort(c("Problem while {step}.", i = "Error occurred in the {ordinal(i)} layer."),
#   .         call = layers[[i]]$constructor, parent = cnd)
#   . })
# 20. tryCatch(withCallingHandlers(expr, condition = function(cnd) {
#   .     {
#   .         .__handler_frame__. <- TRUE
#   .         .__setup_frame__. <- frame
#   .         if (inherits(cnd, "message")) {
#   .             except <- c("warning", "error")
#   .         }
#   .         else if (inherits(cnd, "warning")) {
#   .             except <- "error"
#   .         }
#   .         else {
#   .             except <- ""
#   .         }
#   .     }
#   .     while (!is_null(cnd)) {
#   .         if (inherits(cnd, "error")) {
#   .             out <- handlers[[1L]](cnd)
#   .             if (!inherits(out, "rlang_zap"))
#   .                 throw(out)
#   .         }
#   .         inherit <- .subset2(.subset2(cnd, "rlang"), "inherit")
#   .         if (is_false(inherit)) {
#   .             return()
#   .         }
#   .         cnd <- .subset2(cnd, "parent")
#   .     }
#   . }), stackOverflowError = handlers[[1L]])
# 21. tryCatchList(expr, classes, parentenv, handlers)
# 22. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 23. doTryCatch(return(expr), name, parentenv, handler)
# 24. withCallingHandlers(expr, condition = function(cnd) {
#   .     {
#   .         .__handler_frame__. <- TRUE
#   .         .__setup_frame__. <- frame
#   .         if (inherits(cnd, "message")) {
#   .             except <- c("warning", "error")
#   .         }
#   .         else if (inherits(cnd, "warning")) {
#   .             except <- "error"
#   .         }
#   .         else {
#   .             except <- ""
#   .         }
#   .     }
#   .     while (!is_null(cnd)) {
#   .         if (inherits(cnd, "error")) {
#   .             out <- handlers[[1L]](cnd)
#   .             if (!inherits(out, "rlang_zap"))
#   .                 throw(out)
#   .         }
#   .         inherit <- .subset2(.subset2(cnd, "rlang"), "inherit")
#   .         if (is_false(inherit)) {
#   .             return()
#   .         }
#   .         cnd <- .subset2(cnd, "parent")
#   .     }
#   . })
# 25. f(l = layers[[i]], d = data[[i]])
# 26. l$compute_statistic(d, layout)
# 27. compute_statistic(..., self = self)
# 28. self$stat$setup_params(data, self$stat_params)
# 29. setup_params(..., self = self)
# 30. cli::cli_abort("{.fn {snake_class(self)}} must only have an {.field x} {.emph or} {.field y} aesthetic.")
# 31. rlang::abort(message, ..., call = call, use_cli_format = TRUE,
#   .     .frame = .frame)
# 32. signal_abort(cnd, .file)
# 33. signalCondition(cnd)
# 34. (function (cnd)
#   . {
#   .     {
#   .         .__handler_frame__. <- TRUE
#   .         .__setup_frame__. <- frame
#   .         if (inherits(cnd, "message")) {
#   .             except <- c("warning", "error")
#   .         }
#   .         else if (inherits(cnd, "warning")) {
#   .             except <- "error"
#   .         }
#   .         else {
#   .             except <- ""
#   .         }
#   .     }
#   .     while (!is_null(cnd)) {
#   .         if (inherits(cnd, "error")) {
#   .             out <- handlers[[1L]](cnd)
#   .             if (!inherits(out, "rlang_zap"))
#   .                 throw(out)
#   .         }
#   .         inherit <- .subset2(.subset2(cnd, "rlang"), "inherit")
#   .         if (is_false(inherit)) {
#   .             return()
#   .         }
#   .         cnd <- .subset2(cnd, "parent")
#   .     }
#   . })(structure(list(message = "`stat_count()` must only have an \033x\033 \033or\033 \033y\033 aesthetic.",
#   .     trace = structure(list(call = list(IRkernel::main(), kernel$run(),
#   .         handle_shell(), executor$execute(msg), tryCatch(evaluate(request$content$code,
#   .             envir = .GlobalEnv, output_handler = oh, stop_on_error = 1L),
#   .             interrupt = function(cond) {
#   .                 log_debug("Interrupt during execution")
#   .                 interrupted <<- TRUE
#   .             }, error = .self$handle_error), tryCatchList(expr,
#   .             classes, parentenv, handlers), tryCatchOne(tryCatchList(expr,
#   .             names[-nh], parentenv, handlers[-nh]), names[nh],
#   .             parentenv, handlers[[nh]]), doTryCatch(return(expr),
#   .             name, parentenv, handler), tryCatchList(expr, names[-nh],
#   .             parentenv, handlers[-nh]), tryCatchOne(expr, names,
#   .             parentenv, handlers[[1L]]), doTryCatch(return(expr),
#   .             name, parentenv, handler), evaluate(request$content$code,
#   .             envir = .GlobalEnv, output_handler = oh, stop_on_error = 1L),
#   .         withRestarts(with_handlers({
#   .             for (expr in tle$exprs) {
#   .                 ev <- withVisible(eval(expr, envir))
#   .                 watcher$capture_plot_and_output()
#   .                 watcher$print_value(ev$value, ev$visible, envir)
#   .             }
#   .             TRUE
#   .         }, handlers), eval_continue = function() TRUE, eval_stop = function() FALSE),
#   .         withRestartList(expr, restarts), withOneRestart(withRestartList(expr,
#   .             restarts[-nr]), restarts[[nr]]), doWithOneRestart(return(expr),
#   .             restart), withRestartList(expr, restarts[-nr]), withOneRestart(expr,
#   .             restarts[[1L]]), doWithOneRestart(return(expr), restart),
#   .         with_handlers({
#   .             for (expr in tle$exprs) {
#   .                 ev <- withVisible(eval(expr, envir))
#   .                 watcher$capture_plot_and_output()
#   .                 watcher$print_value(ev$value, ev$visible, envir)
#   .             }
#   .             TRUE
#   .         }, handlers), eval(call), eval(call), withCallingHandlers(code,
#   .             message = `<fn>`, warning = `<fn>`, error = `<fn>`),
#   .         watcher$print_value(ev$value, ev$visible, envir), withVisible(handle_value(handler,
#   .             value, visible, envir)), handle_value(handler, value,
#   .             visible, envir), handler$value(value, visible), prepare_mimebundle_kernel(obj,
#   .             .self$handle_display_error), prepare_mimebundle(obj,
#   .             "text/plain", error_handler = handle_display_error),
#   .         filter_map(mimetypes, function(mime) {
#   .             tryCatch(withCallingHandlers({
#   .                 if (!mime %in% names(repr::mime2repr))
#   .                   stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#   .                 rpr <- repr::mime2repr[[mime]](obj)
#   .                 if (is.null(rpr))
#   .                   return(NULL)
#   .                 prepare_content(is.raw(rpr), rpr)
#   .             }, error = error_handler), error = outer_handler)
#   .         }), Filter(Negate(is.null), sapply(x, f, simplify = simplify)),
#   .         unlist(lapply(x, f)), lapply(x, f), sapply(x, f, simplify = simplify),
#   .         lapply(X = X, FUN = FUN, ...), FUN(X[[i]], ...), tryCatch(withCallingHandlers({
#   .             if (!mime %in% names(repr::mime2repr))
#   .                 stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#   .             rpr <- repr::mime2repr[[mime]](obj)
#   .             if (is.null(rpr))
#   .                 return(NULL)
#   .             prepare_content(is.raw(rpr), rpr)
#   .         }, error = error_handler), error = outer_handler), tryCatchList(expr,
#   .             classes, parentenv, handlers), tryCatchOne(expr,
#   .             names, parentenv, handlers[[1L]]), doTryCatch(return(expr),
#   .             name, parentenv, handler), withCallingHandlers({
#   .             if (!mime %in% names(repr::mime2repr))
#   .                 stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#   .             rpr <- repr::mime2repr[[mime]](obj)
#   .             if (is.null(rpr))
#   .                 return(NULL)
#   .             prepare_content(is.raw(rpr), rpr)
#   .         }, error = error_handler), repr::mime2repr[[mime]](obj),
#   .         repr_text.default(obj), paste(capture.output(print(obj)),
#   .             collapse = "\n"), capture.output(print(obj)), withVisible(...elt(i)),
#   .         print(obj), print.ggplot(obj), ggplot_build(x), ggplot_build.ggplot(x),
#   .         by_layer(function(l, d) l$compute_statistic(d, layout),
#   .             layers, data, "computing stat"), try_fetch(for (i in seq_along(data)) {
#   .             out[[i]] <- f(l = layers[[i]], d = data[[i]])
#   .         }, error = function(cnd) {
#   .             cli::cli_abort(c("Problem while {step}.", i = "Error occurred in the {ordinal(i)} layer."),
#   .                 call = layers[[i]]$constructor, parent = cnd)
#   .         }), tryCatch(withCallingHandlers(expr, condition = function(cnd) {
#   .             {
#   .                 .__handler_frame__. <- TRUE
#   .                 .__setup_frame__. <- frame
#   .                 if (inherits(cnd, "message")) {
#   .                   except <- c("warning", "error")
#   .                 }
#   .                 else if (inherits(cnd, "warning")) {
#   .                   except <- "error"
#   .                 }
#   .                 else {
#   .                   except <- ""
#   .                 }
#   .             }
#   .             while (!is_null(cnd)) {
#   .                 if (inherits(cnd, "error")) {
#   .                   out <- handlers[[1L]](cnd)
#   .                   if (!inherits(out, "rlang_zap"))
#   .                     throw(out)
#   .                 }
#   .                 inherit <- .subset2(.subset2(cnd, "rlang"), "inherit")
#   .                 if (is_false(inherit)) {
#   .                   return()
#   .                 }
#   .                 cnd <- .subset2(cnd, "parent")
#   .             }
#   .         }), stackOverflowError = handlers[[1L]]), tryCatchList(expr,
#   .             classes, parentenv, handlers), tryCatchOne(expr,
#   .             names, parentenv, handlers[[1L]]), doTryCatch(return(expr),
#   .             name, parentenv, handler), withCallingHandlers(expr,
#   .             condition = function(cnd) {
#   .                 {
#   .                   .__handler_frame__. <- TRUE
#   .                   .__setup_frame__. <- frame
#   .                   if (inherits(cnd, "message")) {
#   .                     except <- c("warning", "error")
#   .                   }
#   .                   else if (inherits(cnd, "warning")) {
#   .                     except <- "error"
#   .                   }
#   .                   else {
#   .                     except <- ""
#   .                   }
#   .                 }
#   .                 while (!is_null(cnd)) {
#   .                   if (inherits(cnd, "error")) {
#   .                     out <- handlers[[1L]](cnd)
#   .                     if (!inherits(out, "rlang_zap"))
#   .                       throw(out)
#   .                   }
#   .                   inherit <- .subset2(.subset2(cnd, "rlang"),
#   .                     "inherit")
#   .                   if (is_false(inherit)) {
#   .                     return()
#   .                   }
#   .                   cnd <- .subset2(cnd, "parent")
#   .                 }
#   .             }), f(l = layers[[i]], d = data[[i]]), l$compute_statistic(d,
#   .             layout), compute_statistic(..., self = self), self$stat$setup_params(data,
#   .             self$stat_params), setup_params(..., self = self),
#   .         cli::cli_abort("{.fn {snake_class(self)}} must only have an {.field x} {.emph or} {.field y} aesthetic."),
#   .         rlang::abort(message, ..., call = call, use_cli_format = TRUE,
#   .             .frame = .frame)), parent = c(0L, 1L, 2L, 3L, 4L,
#   .     5L, 6L, 7L, 6L, 9L, 10L, 4L, 12L, 13L, 14L, 15L, 14L, 17L,
#   .     18L, 12L, 20L, 21L, 20L, 12L, 24L, 24L, 26L, 27L, 28L, 29L,
#   .     30L, 31L, 31L, 30L, 34L, 35L, 36L, 37L, 38L, 39L, 36L, 36L,
#   .     36L, 43L, 43L, 45L, 43L, 43L, 48L, 48L, 50L, 51L, 52L, 53L,
#   .     54L, 55L, 52L, 51L, 58L, 59L, 60L, 61L, 62L, 63L), visible = c(TRUE,
#   .     TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE,
#   .     TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE,
#   .     TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE,
#   .     TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE,
#   .     TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE,
#   .     TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE, TRUE,
#   .     TRUE, FALSE, FALSE), namespace = c("IRkernel", NA, "IRkernel",
#   .     NA, "base", "base", "base", "base", "base", "base", "base",
#   .     "evaluate", "base", "base", "base", "base", "base", "base",
#   .     "base", "evaluate", "base", "base", "base", NA, "base", "evaluate",
#   .     NA, "IRkernel", "IRdisplay", "IRdisplay", "base", "base",
#   .     "base", "base", "base", "IRdisplay", "base", "base", "base",
#   .     "base", "base", NA, "repr", "base", "utils", "base", "base",
#   .     "ggplot2", "ggplot2", "ggplot2", "ggplot2", "rlang", "base",
#   .     "base", "base", "base", "base", "ggplot2", NA, "ggplot2",
#   .     NA, "ggplot2", "cli", "rlang"), scope = c("::", NA, "local",
#   .     NA, "::", "local", "local", "local", "local", "local", "local",
#   .     "::", "::", "local", "local", "local", "local", "local",
#   .     "local", ":::", "::", "::", "::", NA, "::", ":::", NA, ":::",
#   .     "::", ":::", "::", "::", "::", "::", "::", "local", "::",
#   .     "local", "local", "local", "::", NA, ":::", "::", "::", "::",
#   .     "::", ":::", "::", ":::", ":::", "::", "::", "local", "local",
#   .     "local", "::", "local", NA, "local", NA, "local", "::", "::"
#   .     ), error_frame = c(FALSE, FALSE, FALSE, FALSE, FALSE, FALSE,
#   .     FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE,
#   .     FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE,
#   .     FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE,
#   .     FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE,
#   .     FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE,
#   .     FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE, FALSE,
#   .     FALSE, TRUE, FALSE, FALSE)), row.names = c(NA, -64L), version = 2L, class = c("rlang_trace",
#   .     "rlib_trace", "tbl", "data.frame")), parent = NULL, rlang = list(
#   .         inherit = TRUE), call = setup_params(..., self = self),
#   .     use_cli_format = TRUE), class = c("rlang_error", "error",
#   . "condition")))
# 35. handlers[[1L]](cnd)
# 36. cli::cli_abort(c("Problem while {step}.", i = "Error occurred in the {ordinal(i)} layer."),
#   .     call = layers[[i]]$constructor, parent = cnd)
# 37. rlang::abort(message, ..., call = call, use_cli_format = TRUE,
#   .     .frame = .frame)
# 38. signal_abort(cnd, .file)

# %%
ggplot(data = diamonds) +
  geom_bar(mapping = aes(x = cut, y = stat(prop), group = 1))
# Out:
# Warning message:
# “`stat(prop)` was deprecated in ggplot2 3.4.0.
# ℹ Please use `after_stat(prop)` instead.”
# plot without title

# %% [markdown]
# 3.7.1 Exercises
# 1. What is the default geom associated with stat_summary()? How could you rewrite the previous plot to use that geom function instead of the stat function?
# 2. What does geom_col() do? How is it different to geom_bar()?
# 3. Most geoms and stats come in pairs that are almost always used in concert. Read through the documentation and make a list of all the pairs. What do they have in common?
# 4. What variables does stat_smooth() compute? What parameters control its behaviour?
# 5. In our proportion bar chart, we need to set group = 1. Why? In other words what is the problem with these two graphs?
# ```
# ggplot(data = diamonds) +
#   geom_bar(mapping = aes(x = cut, y = after_stat(prop)))
# ggplot(data = diamonds) +
#   geom_bar(mapping = aes(x = cut, fill = color, y = after_stat(prop)))
# ```

# %% [markdown]
# ### Position adjustments

# %% [markdown]
# You can colour a bar chart using either the colour aesthetic, or, more usefully, fill:

# %%
ggplot(data = diamonds) +
  geom_bar(mapping = aes(x = cut, colour = cut))
ggplot(data = diamonds) +
  geom_bar(mapping = aes(x = cut, fill = cut))
# Out:
# plot without title
# plot without title

# %% [markdown]
# If you map the fill aesthetic to another variable, like clarity, the bars are automatically stacked.

# %%
ggplot(data = diamonds) +
  geom_bar(mapping = aes(x = cut, fill = clarity))
# Out:
# plot without title

# %% [markdown]
# The stacking is performed automatically by the position adjustment specified by the position argument. If you don’t want a stacked bar chart, you can use one of three other options: "identity", "dodge" or "fill".

# %%
ggplot(data = diamonds) +
  geom_bar(mapping = aes(x = cut, fill = clarity), position = "dodge")
# Out:
# plot without title

# %%
ggplot(data = diamonds) +
  geom_bar(mapping = aes(x = cut, fill = clarity), position = "fill")
# Out:
# plot without title

# %% [markdown]
# #### Think how you will visualize a distribution of departure delay (dep_delay).

# %%
flights %>% group_by(origin) %>%
summarise(delay = mean(dep_delay, na.rm = TRUE), sd_delay = sd(dep_delay, na.rm = TRUE))
# Out:
#   origin delay    sd_delay
# 1 EWR    15.10795 41.32370
# 2 JFK    12.11216 39.03507
# 3 LGA    10.34688 39.99302

# %%
flights %>% ggplot(aes(x = origin, y=dep_delay )) + geom_boxplot()
# Out:
# Warning message:
# “Removed 8255 rows containing non-finite outside the scale range
# (`stat_boxplot()`).”
# plot without title

# %%
flights %>% ggplot(aes(x = origin, y=dep_delay )) + geom_violin()
# Out:
# Warning message:
# “Removed 8255 rows containing non-finite outside the scale range
# (`stat_ydensity()`).”
# plot without title

# %% [markdown]
# #### Think how you will visualize monthly departure delay

# %%
flights %>% group_by(month) %>% summarise(delay = mean(dep_delay, na.rm = TRUE), delay_N = n(), delay_sd = sd(dep_delay, na.rm = TRUE))
# Out:
#    month delay     delay_N delay_sd
# 1   1    10.036665 27004   36.39031
# 2   2    10.816843 24951   36.26655
# 3   3    13.227076 28834   40.13097
# 4   4    13.938038 28330   42.96626
# 5   5    12.986859 28796   39.35283
# 6   6    20.846332 28243   51.45694
# 7   7    21.727787 29425   51.61608
# 8   8    12.611040 29327   37.66692
# 9   9     6.722476 27574   35.61480
# 10 10     6.243988 28889   29.67176
# 11 11     5.435362 27268   27.58836
# 12 12    16.576688 28135   41.87681

# %%
flights %>% group_by(month) %>%
  summarise(delay = mean(dep_delay, na.rm = TRUE), delay_N = n(), delay_sd = sd(dep_delay, na.rm = TRUE))  %>%
  ggplot(aes(x = month, y = delay) ) +
    geom_bar(stat = "identity", position = "dodge")
# Out:
# plot without title

# %%
flights %>% group_by(month) %>%
  summarise(delay = mean(dep_delay, na.rm = TRUE), delay_N = n(), delay_sd = sd(dep_delay, na.rm = TRUE))  %>%
  ggplot(aes(x = month, y = delay) ) +
    geom_bar(stat = "identity") +
    geom_errorbar(aes(ymin=delay-delay_sd, ymax=delay+delay_sd), width=0.4, colour="orange", alpha=0.9, linewidth=1.3)
# Out:
# plot without title

# %%
flights %>% ggplot(aes(x = factor(month), y=dep_delay)) + geom_violin()
# Out:
# Warning message:
# “Removed 8255 rows containing non-finite outside the scale range
# (`stat_ydensity()`).”
# plot without title

# %% [markdown]
# #### cordinate flip

# %%
ggplot(data = mpg, mapping = aes(x = class, y = hwy)) +
  geom_boxplot()
# Out:
# plot without title

# %%
ggplot(data = mpg, mapping = aes(x = class, y = hwy)) +
  geom_boxplot() +
  coord_flip()
# Out:
# plot without title

# %%
ggplot(data = mpg, mapping = aes(x = class, y = hwy)) +
  geom_violin() +
  coord_flip()
# Out:
# plot without title

# %%
ggplot(data = mpg, mapping = aes(x = class, y = hwy)) +
  geom_violin() + geom_boxplot(width=0.1, color="grey", alpha=0.2)
# Out:
# plot without title

# %% [markdown]
# ### Theme

# %%
png("Fig_test.png", width = 7, height = 7, units = 'in', res = 300)
ggplot(data = mpg) +
  geom_point(mapping = aes(x = displ, y = hwy)) + theme_bw() +
  theme(axis.line= element_line(size=.8, colour = "black"),
        panel.grid.minor = element_blank(),
        panel.border = element_blank(),
        text = element_text(size = 25))
dev.off()
# Out:
# agg_record_661476296
#                    2

# %%
ggplot(data = mpg) +
  geom_point(mapping = aes(x = displ, y = hwy)) + theme_bw() +
  theme(axis.line= element_line(size=.8, colour = "black"),
        #panel.grid.minor = element_blank(),
        #panel.border = element_blank(),
        text = element_text(size = 25))
# Out:
# plot without title

# %%
ggplot(data = mpg) +
  geom_point(mapping = aes(x = displ, y = hwy)) + theme_dark() +
  theme(axis.line= element_line(size=.8, colour = "black"),
        panel.grid.minor = element_blank(),
        panel.border = element_blank(),
        text = element_text(size = 25))
# Out:
# plot without title

# %%
ggplot(data = mpg) +
  geom_point(mapping = aes(x = displ, y = hwy)) + theme_test() +
  theme(axis.line= element_line(size=.8, colour = "black"),
        panel.grid.minor = element_blank(),
        panel.border = element_blank(),
        text = element_text(size = 25))
# Out:
# plot without title

# %%
ggplot(data = mpg) + theme_bw() +
  geom_point(mapping = aes(x = displ, y = hwy)) +
  facet_grid(drv ~ cyl)  +
  theme(axis.line= element_line(size=.8, colour = "black"),
        panel.grid.minor = element_blank(),
        text = element_text(size = 25))
# Out:
# plot without title

# %%
ggplot(data = diamonds) +
  geom_bar(mapping = aes(x = cut, fill = clarity)) + theme_bw() +
  theme(axis.line= element_line(colour = "black"),
        panel.grid.minor = element_blank(),
#        panel.border = element_blank(),
        text = element_text(size = 25),
        axis.text.x = element_text(angle= 45, vjust = .5)
        )
# Out:
# plot without title

# %%
# png("Fig.png", width = 7, height = 3, units = 'in', res = 300)
ggplot(data = diamonds) +
  geom_bar(mapping = aes(x = cut, fill = clarity)) + theme_bw() +
  theme(axis.line= element_line(colour = "black"),
        panel.grid.minor = element_blank(),
#        panel.border = element_blank(),
        text = element_text(size = 25),
#        axis.text.x = element_text(angle= 45, vjust = .5)
        ) +   coord_flip()
#dev.off()
# Out:
# plot without title

# %%
ggplot(data = mpg, mapping = aes(x = class, y = hwy)) +
  geom_violin() + geom_boxplot(width=0.1, color="grey", alpha=0.2) + theme_minimal()+
  theme(axis.line= element_line(colour = "black"),
        panel.grid.minor = element_blank(),
        panel.border = element_blank(),
        text = element_text(size = 30),
        ) +   coord_flip()
# Out:
# plot without title
